# %%
import os
import argparse
import numpy as np
import json
import csv
import rasterio

# shapely.geometry import mapping, Polygon
# import fiona # only required for exporting to shapefiles

# %%
# ingest the image
infile = "mosaics/SteepleJason_Bubble_Nov2019_transparent_mosaic_group1.tif"

img_dir = infile.split(".")[0]
prj_name = img_dir.split("/")[-1]

#infile_hump = 'mosaics/SteepleJason_Hump_Nov2019_transparent_mosaic_group1.tif'

#img_dir_hump = infile_hump.split(".")[0]
#prj_name_hump = img_dir_hump.split("/")[-1]

# %%
img_dir
# Out:
# 'mosaics/SteepleJason_Bubble_Nov2019_transparent_mosaic_group1'

# %%
# open the output from albatross_detection

with open('new_detections.json') as f:
    detected_labels = json.load(f)

# %%
# open the previous training data

#with open(img_dir + '/via_project_18Mar2020_11h08m45s.json') as f:
    #existing_labels = json.load(f)

# %%
len(detected_labels)
# Out:
# 509

# %%
image_annotations = []
for key, value in detected_labels.items():
    #print(key)
    annotation = [[key][0].split("/")[-1]]
    detections = []
    for item in value:
        box = item['box']
        detections.append(box)
        print(item)
    annotation.append(detections)
    image_annotations.append(annotation)
# Out:
# {'box': [744, 184, 812, 289], 'label': 0, 'score': 0.8964086174964905}
# {'box': [6, 337, 102, 402], 'label': 0, 'score': 0.8721719980239868}
# {'box': [232, 46, 323, 118], 'label': 0, 'score': 0.8716826438903809}
# {'box': [360, 732, 421, 840], 'label': 0, 'score': 0.8622096180915833}
# {'box': [173, 375, 253, 488], 'label': 0, 'score': 0.8472293019294739}
# {'box': [372, 82, 469, 177], 'label': 0, 'score': 0.8195050954818726}
# {'box': [890, 524, 974, 629], 'label': 0, 'score': 0.804831326007843}
# {'box': [507, 839, 574, 938], 'label': 0, 'score': 0.7919514775276184}
# {'box': [455, 623, 541, 709], 'label': 0, 'score': 0.7910252213478088}
# {'box': [553, 464, 650, 540], 'label': 0, 'score': 0.7622179388999939}
# {'box': [616, 684, 711, 752], 'label': 0, 'score': 0.7487940788269043}
# {'box': [751, 396, 822, 485], 'label': 0, 'score': 0.7350351810455322}
# {'box': [154, 202, 217, 304], 'label': 0, 'score': 0.7319661378860474}
# {'box': [351, 237, 425, 352], 'label': 0, 'score': 0.7244158387184143}
# {'box': [537, 246, 612, 348], 'label': 0, 'score': 0.7068045735359192}
# {'box': [912, 241, 982, 346], 'label': 0, 'score': 0.7052263021469116}
# {'box': [852, 44, 963, 115], 'label': 0, 'score': 0.7010477185249329}
# {'box': [584, 31, 673, 108], 'label': 0, 'score': 0.6818318963050842}
# {'box': [140, 758, 254, 833], 'label': 0, 'score': 0.667175829410553}
# {'box': [3, 759, 58, 861], 'label': 0, 'score': 0.6572378277778625}
# {'box': [380, 434, 485, 505], 'label': 0, 'score': 0.640824019908905}
# {'box': [68, 21, 179, 82], 'label': 0, 'score': 0.607244074344635}
# {'box': [861, 702, 940, 806], 'label': 0, 'score': 0.5478011965751648}
# {'box': [170, 82, 244, 197], 'label': 0, 'score': 0.9614615440368652}
# {'box': [310, 825, 381, 936], 'label': 0, 'score': 0.9192373752593994}
# {'box': [902, 535, 989, 629], 'label': 0, 'score': 0.8792340159416199}
# {'box': [160, 317, 250, 399], 'label': 0, 'score': 0.8501430749893188}
# {'box': [724, 439, 813, 518], 'label': 0, 'score': 0.8148161172866821}
# {'box': [119, 858, 226, 934], 'label': 0, 'score': 0.8119179606437683}
# {'box': [330, 653, 406, 752], 'label': 0, 'score': 0.8077987432479858}
# {'box': [530, 137, 614, 237], 'label': 0, 'score': 0.7966750264167786}
# {'box': [496, 697, 574, 792], 'label': 0, 'score': 0.7915909290313721}
# {'box': [874, 379, 968, 476], 'label': 0, 'score': 0.7909136414527893}
# {'box': [783, 74, 849, 175], 'label': 0, 'score': 0.779018759727478}
# {'box': [321, 185, 435, 258], 'label': 0, 'score': 0.7768031358718872}
# {'box': [6, 180, 99, 269], 'label': 0, 'score': 0.7617194056510925}
# {'box': [130, 654, 215, 750], 'label': 0, 'score': 0.759265661239624}
# {'box': [376, 1, 458, 101], 'label': 0, 'score': 0.7564600706100464}
# {'box': [73, 446, 145, 547], 'label': 0, 'score': 0.7379159331321716}
# {'box': [489, 505, 564, 614], 'label': 0, 'score': 0.7127185463905334}
# {'box': [617, 805, 697, 907], 'label': 0, 'score': 0.7041676640510559}
# {'box': [392, 340, 479, 440], 'label': 0, 'score': 0.6967047452926636}
# {'box': [863, 211, 963, 306], 'label': 0, 'score': 0.6799024343490601}
# {'box': [654, 611, 742, 697], 'label': 0, 'score': 0.6396540999412537}
# {'box': [690, 272, 772, 360], 'label': 0, 'score': 0.6009492874145508}
# {'box': [762, 926, 854, 995], 'label': 0, 'score': 0.5228114128112793}
# {'box': [439, 910, 539, 986], 'label': 0, 'score': 0.5224308371543884}
# {'box': [141, 386, 203, 488], 'label': 0, 'score': 0.9005550146102905}
# {'box': [476, 551, 548, 658], 'label': 0, 'score': 0.793240487575531}
# {'box': [272, 706, 340, 812], 'label': 0, 'score': 0.7725071907043457}
# {'box': [143, 828, 222, 933], 'label': 0, 'score': 0.7697562575340271}
# {'box': [806, 411, 895, 499], 'label': 0, 'score': 0.6281253099441528}
# {'box': [559, 331, 622, 433], 'label': 0, 'score': 0.5770006775856018}
# {'box': [217, 560, 315, 645], 'label': 0, 'score': 0.5683757066726685}
# {'box': [834, 721, 920, 792], 'label': 0, 'score': 0.9172793626785278}
# {'box': [739, 1, 813, 80], 'label': 0, 'score': 0.8450852036476135}
# {'box': [355, 818, 431, 898], 'label': 0, 'score': 0.8128583431243896}
# {'box': [523, 204, 608, 266], 'label': 0, 'score': 0.804213285446167}
# {'box': [498, 515, 577, 594], 'label': 0, 'score': 0.7920699715614319}
# {'box': [870, 148, 961, 209], 'label': 0, 'score': 0.7891637086868286}
# {'box': [789, 294, 857, 373], 'label': 0, 'score': 0.7808675169944763}
# {'box': [592, 3, 652, 87], 'label': 0, 'score': 0.7774745225906372}
# {'box': [668, 785, 758, 846], 'label': 0, 'score': 0.7680184245109558}
# {'box': [552, 320, 638, 391], 'label': 0, 'score': 0.758355438709259}
# {'box': [28, 412, 77, 505], 'label': 0, 'score': 0.737322986125946}
# {'box': [671, 624, 742, 697], 'label': 0, 'score': 0.7306970357894897}
# {'box': [227, 716, 296, 800], 'label': 0, 'score': 0.7200583815574646}
# {'box': [172, 43, 266, 100], 'label': 0, 'score': 0.7185598015785217}
# {'box': [856, 480, 918, 569], 'label': 0, 'score': 0.7155929207801819}
# {'box': [823, 850, 895, 934], 'label': 0, 'score': 0.7122781872749329}
# {'box': [211, 184, 279, 268], 'label': 0, 'score': 0.6858038902282715}
# {'box': [654, 289, 726, 376], 'label': 0, 'score': 0.6758947372436523}
# {'box': [408, 228, 461, 311], 'label': 0, 'score': 0.6606044173240662}
# {'box': [354, 604, 444, 659], 'label': 0, 'score': 0.654799222946167}
# {'box': [357, 407, 440, 473], 'label': 0, 'score': 0.6365067958831787}
# {'box': [26, 30, 109, 91], 'label': 0, 'score': 0.6169247031211853}
# {'box': [83, 664, 171, 730], 'label': 0, 'score': 0.6004746556282043}
# {'box': [558, 862, 611, 946], 'label': 0, 'score': 0.559680700302124}
# {'box': [712, 447, 782, 528], 'label': 0, 'score': 0.5542661547660828}
# {'box': [477, 720, 552, 797], 'label': 0, 'score': 0.5414047241210938}
# {'box': [366, 87, 429, 165], 'label': 0, 'score': 0.5203548073768616}
# {'box': [806, 316, 882, 423], 'label': 0, 'score': 0.9343045949935913}
# {'box': [468, 603, 564, 697], 'label': 0, 'score': 0.8579245805740356}
# {'box': [249, 87, 339, 185], 'label': 0, 'score': 0.8132967948913574}
# {'box': [8, 235, 71, 334], 'label': 0, 'score': 0.7830810546875}
# {'box': [42, 861, 136, 956], 'label': 0, 'score': 0.771549642086029}
# {'box': [194, 399, 280, 519], 'label': 0, 'score': 0.7297757863998413}
# {'box': [698, 531, 799, 627], 'label': 0, 'score': 0.7267486453056335}
# {'box': [456, 90, 561, 176], 'label': 0, 'score': 0.7006569504737854}
# {'box': [897, 500, 971, 604], 'label': 0, 'score': 0.684275209903717}
# {'box': [409, 341, 517, 416], 'label': 0, 'score': 0.6661592125892639}
# {'box': [731, 53, 816, 155], 'label': 0, 'score': 0.6405175924301147}
# {'box': [728, 904, 800, 996], 'label': 0, 'score': 0.6211010217666626}
# {'box': [181, 230, 254, 337], 'label': 0, 'score': 0.6076285243034363}
# {'box': [233, 920, 328, 994], 'label': 0, 'score': 0.5990022420883179}
# {'box': [389, 821, 480, 923], 'label': 0, 'score': 0.5833119750022888}
# {'box': [577, 264, 689, 333], 'label': 0, 'score': 0.5788755416870117}
# {'box': [210, 721, 282, 817], 'label': 0, 'score': 0.5498715043067932}
# {'box': [891, 920, 979, 992], 'label': 0, 'score': 0.5287753343582153}
# {'box': [599, 718, 712, 789], 'label': 0, 'score': 0.5122626423835754}
# {'box': [39, 176, 87, 262], 'label': 0, 'score': 0.8747879266738892}
# {'box': [894, 99, 965, 197], 'label': 0, 'score': 0.8720766305923462}
# {'box': [67, 357, 120, 440], 'label': 0, 'score': 0.8658833503723145}
# {'box': [261, 611, 339, 689], 'label': 0, 'score': 0.8507874011993408}
# {'box': [451, 392, 533, 447], 'label': 0, 'score': 0.8252354264259338}
# {'box': [733, 237, 820, 295], 'label': 0, 'score': 0.7948594689369202}
# {'box': [447, 646, 539, 703], 'label': 0, 'score': 0.7835796475410461}
# {'box': [862, 874, 920, 956], 'label': 0, 'score': 0.779712975025177}
# {'box': [200, 857, 285, 929], 'label': 0, 'score': 0.7733843326568604}
# {'box': [529, 805, 617, 873], 'label': 0, 'score': 0.7658205628395081}
# {'box': [165, 698, 227, 789], 'label': 0, 'score': 0.7432354688644409}
# {'box': [619, 148, 713, 202], 'label': 0, 'score': 0.733078122138977}
# {'box': [328, 215, 386, 296], 'label': 0, 'score': 0.7191984057426453}
# {'box': [324, 470, 399, 544], 'label': 0, 'score': 0.6739780306816101}
# {'box': [727, 421, 787, 512], 'label': 0, 'score': 0.6698187589645386}
# {'box': [579, 348, 666, 410], 'label': 0, 'score': 0.6565205454826355}
# {'box': [368, 799, 431, 885], 'label': 0, 'score': 0.6499854326248169}
# {'box': [430, 268, 506, 329], 'label': 0, 'score': 0.632068932056427}
# {'box': [833, 669, 914, 725], 'label': 0, 'score': 0.6263553500175476}
# {'box': [949, 740, 990, 814], 'label': 0, 'score': 0.6168450117111206}
# {'box': [234, 355, 298, 437], 'label': 0, 'score': 0.6055896282196045}
# {'box': [357, 54, 428, 135], 'label': 0, 'score': 0.5655636191368103}
# {'box': [887, 284, 979, 342], 'label': 0, 'score': 0.5592678189277649}
# {'box': [6, 783, 77, 834], 'label': 0, 'score': 0.5583660006523132}
# {'box': [191, 199, 271, 257], 'label': 0, 'score': 0.517255961894989}
# {'box': [107, 555, 171, 635], 'label': 0, 'score': 0.5071523189544678}
# {'box': [490, 29, 558, 138], 'label': 0, 'score': 0.8464941382408142}
# {'box': [147, 428, 222, 536], 'label': 0, 'score': 0.7679290175437927}
# {'box': [358, 495, 471, 565], 'label': 0, 'score': 0.6769824028015137}
# {'box': [502, 294, 611, 359], 'label': 0, 'score': 0.6723145842552185}
# {'box': [855, 268, 930, 355], 'label': 0, 'score': 0.6374856233596802}
# {'box': [447, 901, 549, 983], 'label': 0, 'score': 0.5730767250061035}
# {'box': [304, 668, 377, 772], 'label': 0, 'score': 0.5614018440246582}
# {'box': [312, 206, 411, 276], 'label': 0, 'score': 0.5197756886482239}
# {'box': [783, 6, 867, 80], 'label': 0, 'score': 0.9445090293884277}
# {'box': [584, 802, 651, 896], 'label': 0, 'score': 0.9397121071815491}
# {'box': [925, 340, 992, 433], 'label': 0, 'score': 0.9117036461830139}
# {'box': [813, 260, 885, 351], 'label': 0, 'score': 0.8988510966300964}
# {'box': [421, 231, 510, 297], 'label': 0, 'score': 0.8923934102058411}
# {'box': [377, 835, 467, 889], 'label': 0, 'score': 0.8891782164573669}
# {'box': [911, 105, 977, 197], 'label': 0, 'score': 0.8266391754150391}
# {'box': [315, 654, 408, 714], 'label': 0, 'score': 0.8194893002510071}
# {'box': [99, 872, 186, 937], 'label': 0, 'score': 0.8154360055923462}
# {'box': [482, 941, 576, 990], 'label': 0, 'score': 0.7896264791488647}
# {'box': [595, 121, 672, 214], 'label': 0, 'score': 0.7398775815963745}
# {'box': [774, 790, 832, 875], 'label': 0, 'score': 0.7237981557846069}
# {'box': [894, 658, 945, 748], 'label': 0, 'score': 0.7217658758163452}
# {'box': [786, 578, 850, 660], 'label': 0, 'score': 0.6883605718612671}
# {'box': [757, 434, 855, 491], 'label': 0, 'score': 0.6784858107566833}
# {'box': [616, 488, 677, 577], 'label': 0, 'score': 0.6208634376525879}
# {'box': [484, 373, 571, 445], 'label': 0, 'score': 0.5752889513969421}
# {'box': [659, 322, 724, 394], 'label': 0, 'score': 0.5494180917739868}
# {'box': [232, 736, 314, 860], 'label': 0, 'score': 0.8729856610298157}
# {'box': [222, 540, 329, 611], 'label': 0, 'score': 0.8695195317268372}
# {'box': [729, 826, 841, 896], 'label': 0, 'score': 0.8657912611961365}
# {'box': [483, 574, 588, 658], 'label': 0, 'score': 0.8636928200721741}
# {'box': [883, 572, 972, 695], 'label': 0, 'score': 0.8249625563621521}
# {'box': [763, 463, 859, 535], 'label': 0, 'score': 0.7892025709152222}
# {'box': [373, 173, 484, 269], 'label': 0, 'score': 0.7809102535247803}
# {'box': [874, 338, 972, 435], 'label': 0, 'score': 0.7454763054847717}
# {'box': [729, 376, 806, 488], 'label': 0, 'score': 0.7369142174720764}
# {'box': [104, 906, 213, 985], 'label': 0, 'score': 0.7349661588668823}
# {'box': [29, 84, 116, 207], 'label': 0, 'score': 0.7088663578033447}
# {'box': [796, 134, 884, 244], 'label': 0, 'score': 0.6892560124397278}
# {'box': [934, 784, 997, 900], 'label': 0, 'score': 0.5847892761230469}
# {'box': [213, 90, 329, 177], 'label': 0, 'score': 0.5757039189338684}
# {'box': [589, 215, 698, 286], 'label': 0, 'score': 0.5585442781448364}
# {'box': [599, 61, 680, 176], 'label': 0, 'score': 0.9234810471534729}
# {'box': [812, 61, 908, 128], 'label': 0, 'score': 0.8255850076675415}
# {'box': [403, 209, 495, 264], 'label': 0, 'score': 0.7813466787338257}
# {'box': [921, 259, 988, 363], 'label': 0, 'score': 0.6928957104682922}
# {'box': [410, 691, 493, 781], 'label': 0, 'score': 0.9568545818328857}
# {'box': [533, 756, 627, 850], 'label': 0, 'score': 0.947422981262207}
# {'box': [748, 779, 855, 853], 'label': 0, 'score': 0.9166727662086487}
# {'box': [275, 821, 366, 896], 'label': 0, 'score': 0.8385254144668579}
# {'box': [147, 898, 229, 965], 'label': 0, 'score': 0.8310080170631409}
# {'box': [692, 581, 790, 650], 'label': 0, 'score': 0.8137284517288208}
# {'box': [397, 905, 494, 974], 'label': 0, 'score': 0.7745716571807861}
# {'box': [355, 108, 423, 215], 'label': 0, 'score': 0.8902782797813416}
# {'box': [570, 21, 666, 131], 'label': 0, 'score': 0.8006865978240967}
# {'box': [248, 730, 319, 848], 'label': 0, 'score': 0.7973051071166992}
# {'box': [589, 823, 693, 922], 'label': 0, 'score': 0.7767804861068726}
# {'box': [456, 538, 571, 604], 'label': 0, 'score': 0.7561282515525818}
# {'box': [84, 904, 173, 994], 'label': 0, 'score': 0.7323455810546875}
# {'box': [184, 315, 260, 419], 'label': 0, 'score': 0.6910720467567444}
# {'box': [556, 234, 657, 299], 'label': 0, 'score': 0.6762412786483765}
# {'box': [668, 586, 739, 695], 'label': 0, 'score': 0.6748116612434387}
# {'box': [804, 147, 899, 227], 'label': 0, 'score': 0.6518097519874573}
# {'box': [58, 515, 175, 604], 'label': 0, 'score': 0.640678882598877}
# {'box': [889, 671, 975, 766], 'label': 0, 'score': 0.6363838315010071}
# {'box': [258, 549, 321, 659], 'label': 0, 'score': 0.5419695973396301}
# {'box': [17, 711, 102, 805], 'label': 0, 'score': 0.5398527383804321}
# {'box': [778, 314, 881, 396], 'label': 0, 'score': 0.5002368688583374}
# {'box': [513, 670, 597, 784], 'label': 0, 'score': 0.8953861594200134}
# {'box': [415, 383, 496, 478], 'label': 0, 'score': 0.8496712446212769}
# {'box': [870, 160, 985, 243], 'label': 0, 'score': 0.8311882615089417}
# {'box': [603, 414, 687, 517], 'label': 0, 'score': 0.815392255783081}
# {'box': [804, 381, 914, 470], 'label': 0, 'score': 0.8139735460281372}
# {'box': [127, 529, 209, 631], 'label': 0, 'score': 0.7556300163269043}
# {'box': [561, 894, 675, 960], 'label': 0, 'score': 0.6584170460700989}
# {'box': [744, 769, 814, 868], 'label': 0, 'score': 0.6390740871429443}
# {'box': [50, 699, 134, 800], 'label': 0, 'score': 0.8953929543495178}
# {'box': [80, 453, 158, 564], 'label': 0, 'score': 0.8576714992523193}
# {'box': [393, 529, 481, 604], 'label': 0, 'score': 0.8502255082130432}
# {'box': [563, 839, 639, 931], 'label': 0, 'score': 0.8429481983184814}
# {'box': [753, 827, 837, 910], 'label': 0, 'score': 0.8242536187171936}
# {'box': [616, 421, 681, 530], 'label': 0, 'score': 0.8187012672424316}
# {'box': [624, 211, 701, 312], 'label': 0, 'score': 0.7761864066123962}
# {'box': [77, 103, 147, 211], 'label': 0, 'score': 0.774078905582428}
# {'box': [408, 722, 487, 824], 'label': 0, 'score': 0.7303283214569092}
# {'box': [715, 77, 821, 154], 'label': 0, 'score': 0.6811768412590027}
# {'box': [571, 632, 667, 719], 'label': 0, 'score': 0.6718862652778625}
# {'box': [824, 335, 925, 421], 'label': 0, 'score': 0.6716336607933044}
# {'box': [868, 154, 956, 237], 'label': 0, 'score': 0.647066593170166}
# {'box': [52, 288, 126, 398], 'label': 0, 'score': 0.6404428482055664}
# {'box': [451, 134, 555, 214], 'label': 0, 'score': 0.6197125911712646}
# {'box': [290, 56, 381, 144], 'label': 0, 'score': 0.6108884811401367}
# {'box': [219, 399, 289, 498], 'label': 0, 'score': 0.6071546673774719}
# {'box': [259, 232, 343, 332], 'label': 0, 'score': 0.5692816972732544}
# {'box': [239, 768, 309, 845], 'label': 0, 'score': 0.5177558064460754}
# {'box': [632, 181, 679, 252], 'label': 0, 'score': 0.8465675115585327}
# {'box': [98, 120, 182, 171], 'label': 0, 'score': 0.755925714969635}
# {'box': [836, 107, 924, 160], 'label': 0, 'score': 0.7267683744430542}
# {'box': [713, 2, 783, 77], 'label': 0, 'score': 0.925089418888092}
# {'box': [49, 621, 145, 689], 'label': 0, 'score': 0.9258042573928833}
# {'box': [44, 183, 152, 243], 'label': 0, 'score': 0.8557811379432678}
# {'box': [217, 838, 286, 944], 'label': 0, 'score': 0.8130717277526855}
# {'box': [343, 556, 411, 664], 'label': 0, 'score': 0.9055300951004028}
# {'box': [730, 579, 794, 685], 'label': 0, 'score': 0.8853341341018677}
# {'box': [424, 382, 511, 480], 'label': 0, 'score': 0.8561618328094482}
# {'box': [193, 243, 257, 350], 'label': 0, 'score': 0.8030202388763428}
# {'box': [691, 17, 771, 134], 'label': 0, 'score': 0.7848192453384399}
# {'box': [118, 83, 209, 141], 'label': 0, 'score': 0.7627820372581482}
# {'box': [157, 571, 224, 678], 'label': 0, 'score': 0.7520061731338501}
# {'box': [376, 913, 451, 997], 'label': 0, 'score': 0.750249981880188}
# {'box': [607, 276, 694, 356], 'label': 0, 'score': 0.7481629252433777}
# {'box': [658, 442, 764, 508], 'label': 0, 'score': 0.7422078251838684}
# {'box': [70, 392, 149, 501], 'label': 0, 'score': 0.7232534289360046}
# {'box': [621, 684, 693, 797], 'label': 0, 'score': 0.71322101354599}
# {'box': [879, 25, 941, 141], 'label': 0, 'score': 0.7122175693511963}
# {'box': [2, 239, 63, 346], 'label': 0, 'score': 0.7086731791496277}
# {'box': [345, 225, 453, 288], 'label': 0, 'score': 0.6717079877853394}
# {'box': [109, 797, 177, 899], 'label': 0, 'score': 0.6471286416053772}
# {'box': [478, 764, 593, 823], 'label': 0, 'score': 0.6416531801223755}
# {'box': [787, 200, 869, 294], 'label': 0, 'score': 0.5978990793228149}
# {'box': [531, 567, 592, 680], 'label': 0, 'score': 0.5710229277610779}
# {'box': [833, 381, 930, 478], 'label': 0, 'score': 0.570108950138092}
# {'box': [245, 794, 347, 859], 'label': 0, 'score': 0.5595084428787231}
# {'box': [914, 741, 976, 852], 'label': 0, 'score': 0.5575804114341736}
# {'box': [755, 792, 832, 892], 'label': 0, 'score': 0.5332620143890381}
# {'box': [344, 729, 420, 799], 'label': 0, 'score': 0.5288710594177246}
# {'box': [586, 879, 656, 986], 'label': 0, 'score': 0.9398652911186218}
# {'box': [848, 151, 930, 257], 'label': 0, 'score': 0.905691385269165}
# {'box': [61, 436, 148, 535], 'label': 0, 'score': 0.8974239826202393}
# {'box': [712, 716, 774, 822], 'label': 0, 'score': 0.888317346572876}
# {'box': [177, 699, 257, 802], 'label': 0, 'score': 0.8748538494110107}
# {'box': [537, 40, 620, 128], 'label': 0, 'score': 0.8180592060089111}
# {'box': [223, 315, 300, 413], 'label': 0, 'score': 0.8126062154769897}
# {'box': [523, 648, 608, 752], 'label': 0, 'score': 0.7890264391899109}
# {'box': [670, 522, 750, 617], 'label': 0, 'score': 0.7793220281600952}
# {'box': [367, 710, 443, 811], 'label': 0, 'score': 0.7755118608474731}
# {'box': [261, 101, 358, 167], 'label': 0, 'score': 0.7297677993774414}
# {'box': [624, 297, 733, 375], 'label': 0, 'score': 0.7091658115386963}
# {'box': [436, 242, 549, 304], 'label': 0, 'score': 0.6369749903678894}
# {'box': [776, 906, 852, 993], 'label': 0, 'score': 0.8698297142982483}
# {'box': [414, 867, 503, 969], 'label': 0, 'score': 0.8617560863494873}
# {'box': [65, 269, 145, 373], 'label': 0, 'score': 0.7866206765174866}
# {'box': [410, 443, 477, 552], 'label': 0, 'score': 0.7570486068725586}
# {'box': [927, 235, 994, 337], 'label': 0, 'score': 0.7499781250953674}
# {'box': [515, 613, 607, 702], 'label': 0, 'score': 0.7250064015388489}
# {'box': [645, 179, 738, 271], 'label': 0, 'score': 0.6802541613578796}
# {'box': [140, 119, 238, 205], 'label': 0, 'score': 0.6720348596572876}
# {'box': [419, 242, 506, 340], 'label': 0, 'score': 0.6616374850273132}
# {'box': [527, 74, 613, 155], 'label': 0, 'score': 0.6475151777267456}
# {'box': [642, 433, 736, 506], 'label': 0, 'score': 0.6380842924118042}
# {'box': [310, 748, 385, 859], 'label': 0, 'score': 0.6223809123039246}
# {'box': [721, 344, 811, 435], 'label': 0, 'score': 0.6038271188735962}
# {'box': [227, 593, 320, 660], 'label': 0, 'score': 0.5709907412528992}
# {'box': [316, 98, 406, 181], 'label': 0, 'score': 0.5269362926483154}
# {'box': [730, 521, 802, 629], 'label': 0, 'score': 0.5106732249259949}
# {'box': [811, 721, 913, 785], 'label': 0, 'score': 0.5021929740905762}
# {'box': [282, 226, 354, 335], 'label': 0, 'score': 0.88631272315979}
# {'box': [597, 498, 681, 592], 'label': 0, 'score': 0.8754655718803406}
# {'box': [39, 52, 100, 156], 'label': 0, 'score': 0.8498635292053223}
# {'box': [95, 237, 199, 307], 'label': 0, 'score': 0.8356848359107971}
# {'box': [102, 595, 217, 651], 'label': 0, 'score': 0.8203429579734802}
# {'box': [446, 728, 530, 823], 'label': 0, 'score': 0.815748393535614}
# {'box': [792, 457, 891, 531], 'label': 0, 'score': 0.8067523837089539}
# {'box': [298, 879, 397, 968], 'label': 0, 'score': 0.8056031465530396}
# {'box': [677, 333, 752, 444], 'label': 0, 'score': 0.7985019683837891}
# {'box': [221, 4, 299, 102], 'label': 0, 'score': 0.7857151627540588}
# {'box': [557, 23, 666, 91], 'label': 0, 'score': 0.7789703011512756}
# {'box': [469, 239, 573, 301], 'label': 0, 'score': 0.7678835988044739}
# {'box': [281, 636, 343, 745], 'label': 0, 'score': 0.7625826597213745}
# {'box': [774, 803, 891, 878], 'label': 0, 'score': 0.7566463351249695}
# {'box': [757, 46, 868, 108], 'label': 0, 'score': 0.7352927327156067}
# {'box': [598, 711, 708, 790], 'label': 0, 'score': 0.7268527746200562}
# {'box': [399, 402, 508, 466], 'label': 0, 'score': 0.6888043284416199}
# {'box': [366, 69, 477, 144], 'label': 0, 'score': 0.6832918524742126}
# {'box': [240, 429, 328, 527], 'label': 0, 'score': 0.6496986150741577}
# {'box': [23, 388, 128, 459], 'label': 0, 'score': 0.6092075705528259}
# {'box': [682, 279, 778, 411], 'label': 0, 'score': 0.9690729975700378}
# {'box': [32, 68, 121, 173], 'label': 0, 'score': 0.880851686000824}
# {'box': [592, 777, 706, 861], 'label': 0, 'score': 0.872701108455658}
# {'box': [558, 521, 637, 621], 'label': 0, 'score': 0.8570567965507507}
# {'box': [127, 237, 221, 345], 'label': 0, 'score': 0.8299741148948669}
# {'box': [535, 121, 655, 217], 'label': 0, 'score': 0.8050001859664917}
# {'box': [745, 660, 847, 759], 'label': 0, 'score': 0.7966976761817932}
# {'box': [819, 845, 896, 963], 'label': 0, 'score': 0.7954254150390625}
# {'box': [405, 23, 488, 151], 'label': 0, 'score': 0.773894190788269}
# {'box': [748, 140, 870, 229], 'label': 0, 'score': 0.7298129796981812}
# {'box': [389, 842, 483, 930], 'label': 0, 'score': 0.6851093173027039}
# {'box': [188, 894, 296, 979], 'label': 0, 'score': 0.6838746666908264}
# {'box': [506, 307, 583, 426], 'label': 0, 'score': 0.683768630027771}
# {'box': [232, 604, 348, 681], 'label': 0, 'score': 0.6482430696487427}
# {'box': [437, 674, 545, 757], 'label': 0, 'score': 0.5967212915420532}
# {'box': [98, 452, 181, 571], 'label': 0, 'score': 0.5822895169258118}
# {'box': [213, 67, 323, 164], 'label': 0, 'score': 0.5775507688522339}
# {'box': [303, 416, 411, 484], 'label': 0, 'score': 0.5744642615318298}
# {'box': [214, 588, 272, 674], 'label': 0, 'score': 0.82831209897995}
# {'box': [54, 664, 115, 755], 'label': 0, 'score': 0.8196095824241638}
# {'box': [698, 239, 774, 306], 'label': 0, 'score': 0.8176042437553406}
# {'box': [490, 14, 571, 65], 'label': 0, 'score': 0.7779183387756348}
# {'box': [790, 57, 870, 129], 'label': 0, 'score': 0.7650362253189087}
# {'box': [622, 136, 671, 219], 'label': 0, 'score': 0.7512263655662537}
# {'box': [338, 537, 429, 594], 'label': 0, 'score': 0.701850414276123}
# {'box': [801, 526, 886, 576], 'label': 0, 'score': 0.7007821202278137}
# {'box': [448, 388, 540, 452], 'label': 0, 'score': 0.6797062754631042}
# {'box': [470, 201, 556, 251], 'label': 0, 'score': 0.6653569340705872}
# {'box': [847, 830, 935, 900], 'label': 0, 'score': 0.6460588574409485}
# {'box': [427, 842, 496, 916], 'label': 0, 'score': 0.6390218734741211}
# {'box': [809, 649, 877, 729], 'label': 0, 'score': 0.6064752340316772}
# {'box': [652, 380, 720, 454], 'label': 0, 'score': 0.6028047800064087}
# {'box': [227, 394, 312, 455], 'label': 0, 'score': 0.5884076952934265}
# {'box': [13, 840, 100, 896], 'label': 0, 'score': 0.5713785886764526}
# {'box': [607, 631, 685, 702], 'label': 0, 'score': 0.5668221116065979}
# {'box': [837, 371, 898, 450], 'label': 0, 'score': 0.5650113224983215}
# {'box': [102, 519, 152, 607], 'label': 0, 'score': 0.5449784994125366}
# {'box': [489, 544, 558, 613], 'label': 0, 'score': 0.5050989389419556}
# {'box': [858, 562, 935, 634], 'label': 0, 'score': 0.8758494853973389}
# {'box': [363, 889, 448, 957], 'label': 0, 'score': 0.8592014312744141}
# {'box': [673, 509, 745, 587], 'label': 0, 'score': 0.8498892784118652}
# {'box': [66, 330, 119, 419], 'label': 0, 'score': 0.8343821167945862}
# {'box': [501, 25, 558, 111], 'label': 0, 'score': 0.8148455023765564}
# {'box': [928, 406, 987, 500], 'label': 0, 'score': 0.797268271446228}
# {'box': [499, 468, 564, 547], 'label': 0, 'score': 0.7833939790725708}
# {'box': [395, 147, 491, 203], 'label': 0, 'score': 0.725845992565155}
# {'box': [211, 726, 265, 810], 'label': 0, 'score': 0.7063069343566895}
# {'box': [516, 774, 594, 837], 'label': 0, 'score': 0.6865814924240112}
# {'box': [576, 617, 639, 711], 'label': 0, 'score': 0.6847394704818726}
# {'box': [608, 153, 686, 222], 'label': 0, 'score': 0.679646909236908}
# {'box': [89, 659, 177, 724], 'label': 0, 'score': 0.6744995713233948}
# {'box': [3, 208, 67, 295], 'label': 0, 'score': 0.6734281778335571}
# {'box': [624, 371, 688, 461], 'label': 0, 'score': 0.6481873989105225}
# {'box': [403, 383, 495, 444], 'label': 0, 'score': 0.6465951204299927}
# {'box': [367, 551, 431, 627], 'label': 0, 'score': 0.634945273399353}
# {'box': [904, 690, 958, 784], 'label': 0, 'score': 0.6250128746032715}
# {'box': [348, 741, 434, 799], 'label': 0, 'score': 0.6131508350372314}
# {'box': [868, 866, 919, 947], 'label': 0, 'score': 0.6031345129013062}
# {'box': [770, 400, 829, 484], 'label': 0, 'score': 0.6025257706642151}
# {'box': [41, 50, 131, 114], 'label': 0, 'score': 0.5883367657661438}
# {'box': [266, 99, 356, 157], 'label': 0, 'score': 0.5809354782104492}
# {'box': [697, 265, 793, 320], 'label': 0, 'score': 0.570582389831543}
# {'box': [722, 707, 827, 770], 'label': 0, 'score': 0.5553901195526123}
# {'box': [143, 850, 197, 928], 'label': 0, 'score': 0.552134096622467}
# {'box': [5, 871, 75, 922], 'label': 0, 'score': 0.5383479595184326}
# {'box': [264, 481, 337, 564], 'label': 0, 'score': 0.9429868459701538}
# {'box': [779, 27, 877, 86], 'label': 0, 'score': 0.9131730198860168}
# {'box': [647, 154, 727, 227], 'label': 0, 'score': 0.8253778219223022}
# {'box': [561, 526, 634, 601], 'label': 0, 'score': 0.8237209916114807}
# {'box': [176, 328, 241, 414], 'label': 0, 'score': 0.8054450750350952}
# {'box': [455, 392, 520, 478], 'label': 0, 'score': 0.7656153440475464}
# {'box': [737, 507, 802, 606], 'label': 0, 'score': 0.7645887732505798}
# {'box': [109, 462, 184, 533], 'label': 0, 'score': 0.7318775653839111}
# {'box': [855, 191, 921, 269], 'label': 0, 'score': 0.7203888297080994}
# {'box': [317, 140, 381, 227], 'label': 0, 'score': 0.7076582312583923}
# {'box': [519, 700, 599, 769], 'label': 0, 'score': 0.6951956748962402}
# {'box': [868, 375, 934, 465], 'label': 0, 'score': 0.6950271725654602}
# {'box': [203, 634, 270, 712], 'label': 0, 'score': 0.6820700764656067}
# {'box': [70, 838, 147, 904], 'label': 0, 'score': 0.6810600161552429}
# {'box': [714, 729, 777, 815], 'label': 0, 'score': 0.6653526425361633}
# {'box': [45, 902, 129, 952], 'label': 0, 'score': 0.6603143215179443}
# {'box': [331, 669, 410, 726], 'label': 0, 'score': 0.6542461514472961}
# {'box': [669, 348, 758, 403], 'label': 0, 'score': 0.6364474892616272}
# {'box': [828, 634, 919, 704], 'label': 0, 'score': 0.5628764629364014}
# {'box': [36, 599, 102, 679], 'label': 0, 'score': 0.5569072365760803}
# {'box': [185, 835, 273, 900], 'label': 0, 'score': 0.5288599133491516}
# {'box': [614, 855, 685, 929], 'label': 0, 'score': 0.5144398808479309}
# {'box': [823, 864, 899, 916], 'label': 0, 'score': 0.5030179619789124}
# {'box': [131, 848, 226, 924], 'label': 0, 'score': 0.8729357719421387}
# {'box': [533, 385, 598, 482], 'label': 0, 'score': 0.858654260635376}
# {'box': [420, 722, 529, 798], 'label': 0, 'score': 0.8541088700294495}
# {'box': [101, 300, 199, 371], 'label': 0, 'score': 0.803134024143219}
# {'box': [247, 198, 347, 266], 'label': 0, 'score': 0.749990701675415}
# {'box': [644, 171, 733, 253], 'label': 0, 'score': 0.7303228378295898}
# {'box': [355, 894, 476, 967], 'label': 0, 'score': 0.728439450263977}
# {'box': [621, 934, 735, 988], 'label': 0, 'score': 0.6809819340705872}
# {'box': [605, 368, 694, 450], 'label': 0, 'score': 0.67555171251297}
# {'box': [829, 125, 899, 230], 'label': 0, 'score': 0.6649468541145325}
# {'box': [263, 604, 335, 708], 'label': 0, 'score': 0.6495574116706848}
# {'box': [731, 518, 841, 589], 'label': 0, 'score': 0.601912260055542}
# {'box': [374, 588, 485, 661], 'label': 0, 'score': 0.731199324131012}
# {'box': [729, 381, 816, 477], 'label': 0, 'score': 0.6870512962341309}
# {'box': [337, 480, 416, 575], 'label': 0, 'score': 0.9512459635734558}
# {'box': [286, 117, 366, 220], 'label': 0, 'score': 0.8048698306083679}
# {'box': [763, 62, 856, 155], 'label': 0, 'score': 0.7105278372764587}
# {'box': [847, 690, 946, 771], 'label': 0, 'score': 0.6955785155296326}
# {'box': [533, 153, 632, 233], 'label': 0, 'score': 0.6024286150932312}
# {'box': [113, 693, 237, 753], 'label': 0, 'score': 0.5523899793624878}
# {'box': [874, 229, 939, 308], 'label': 0, 'score': 0.5389294624328613}
# {'box': [595, 900, 659, 994], 'label': 0, 'score': 0.5103673338890076}
# {'box': [76, 794, 154, 904], 'label': 0, 'score': 0.9571965336799622}
# {'box': [751, 34, 865, 100], 'label': 0, 'score': 0.9009327292442322}
# {'box': [435, 464, 552, 535], 'label': 0, 'score': 0.8446900844573975}
# {'box': [827, 340, 898, 437], 'label': 0, 'score': 0.8101821541786194}
# {'box': [669, 184, 763, 269], 'label': 0, 'score': 0.7434029579162598}
# {'box': [805, 522, 896, 607], 'label': 0, 'score': 0.7204564213752747}
# {'box': [255, 501, 359, 579], 'label': 0, 'score': 0.7060194611549377}
# {'box': [634, 403, 706, 510], 'label': 0, 'score': 0.7006860971450806}
# {'box': [387, 627, 488, 712], 'label': 0, 'score': 0.7004787921905518}
# {'box': [42, 487, 139, 555], 'label': 0, 'score': 0.691048800945282}
# {'box': [240, 778, 331, 874], 'label': 0, 'score': 0.6790193319320679}
# {'box': [160, 652, 249, 745], 'label': 0, 'score': 0.6782310009002686}
# {'box': [395, 89, 491, 172], 'label': 0, 'score': 0.6673343181610107}
# {'box': [132, 338, 242, 412], 'label': 0, 'score': 0.6658994555473328}
# {'box': [581, 835, 671, 923], 'label': 0, 'score': 0.5986579060554504}
# {'box': [174, 100, 282, 172], 'label': 0, 'score': 0.5962164402008057}
# {'box': [797, 735, 884, 811], 'label': 0, 'score': 0.5709722638130188}
# {'box': [528, 247, 605, 348], 'label': 0, 'score': 0.563626229763031}
# {'box': [484, 107, 568, 203], 'label': 0, 'score': 0.9024710059165955}
# {'box': [882, 575, 963, 670], 'label': 0, 'score': 0.8884721994400024}
# {'box': [109, 2, 204, 65], 'label': 0, 'score': 0.8548793792724609}
# {'box': [341, 809, 415, 922], 'label': 0, 'score': 0.8318021297454834}
# {'box': [75, 533, 174, 592], 'label': 0, 'score': 0.8301143646240234}
# {'box': [175, 897, 248, 995], 'label': 0, 'score': 0.7820081114768982}
# {'box': [239, 187, 305, 298], 'label': 0, 'score': 0.7811077237129211}
# {'box': [869, 791, 952, 904], 'label': 0, 'score': 0.7738850712776184}
# {'box': [11, 150, 111, 212], 'label': 0, 'score': 0.7180653810501099}
# {'box': [420, 586, 507, 655], 'label': 0, 'score': 0.716632068157196}
# {'box': [646, 557, 731, 669], 'label': 0, 'score': 0.6991864442825317}
# {'box': [658, 753, 772, 824], 'label': 0, 'score': 0.6901177167892456}
# {'box': [845, 41, 937, 117], 'label': 0, 'score': 0.6807053685188293}
# {'box': [544, 417, 611, 516], 'label': 0, 'score': 0.6678455471992493}
# {'box': [423, 265, 489, 368], 'label': 0, 'score': 0.6532926559448242}
# {'box': [89, 729, 203, 793], 'label': 0, 'score': 0.6130014061927795}
# {'box': [729, 435, 835, 502], 'label': 0, 'score': 0.5948498845100403}
# {'box': [846, 193, 951, 263], 'label': 0, 'score': 0.5912337899208069}
# {'box': [664, 67, 762, 159], 'label': 0, 'score': 0.5370969772338867}
# {'box': [125, 877, 209, 947], 'label': 0, 'score': 0.921493649482727}
# {'box': [501, 310, 576, 417], 'label': 0, 'score': 0.8568118810653687}
# {'box': [829, 709, 924, 803], 'label': 0, 'score': 0.7697349786758423}
# {'box': [687, 836, 791, 917], 'label': 0, 'score': 0.767742931842804}
# {'box': [596, 181, 704, 253], 'label': 0, 'score': 0.7347331643104553}
# {'box': [415, 638, 526, 701], 'label': 0, 'score': 0.7172228097915649}
# {'box': [369, 420, 430, 537], 'label': 0, 'score': 0.7166128158569336}
# {'box': [242, 763, 320, 880], 'label': 0, 'score': 0.705748975276947}
# {'box': [893, 521, 961, 622], 'label': 0, 'score': 0.6681415438652039}
# {'box': [76, 146, 166, 244], 'label': 0, 'score': 0.6622770428657532}
# {'box': [806, 219, 889, 323], 'label': 0, 'score': 0.6497058272361755}
# {'box': [394, 86, 506, 169], 'label': 0, 'score': 0.5613253116607666}
# {'box': [453, 819, 542, 901], 'label': 0, 'score': 0.5372199416160583}
# {'box': [230, 56, 329, 137], 'label': 0, 'score': 0.5270212888717651}
# {'box': [876, 60, 972, 148], 'label': 0, 'score': 0.5085117816925049}
# {'box': [201, 572, 262, 642], 'label': 0, 'score': 0.9408714771270752}
# {'box': [779, 487, 833, 548], 'label': 0, 'score': 0.8956066966056824}
# {'box': [58, 716, 134, 767], 'label': 0, 'score': 0.8536534905433655}
# {'box': [715, 279, 794, 326], 'label': 0, 'score': 0.8525543808937073}
# {'box': [493, 407, 559, 480], 'label': 0, 'score': 0.8410980105400085}
# {'box': [842, 833, 894, 918], 'label': 0, 'score': 0.8319713473320007}
# {'box': [187, 782, 257, 857], 'label': 0, 'score': 0.7978507876396179}
# {'box': [675, 851, 737, 931], 'label': 0, 'score': 0.7365546822547913}
# {'box': [913, 384, 991, 433], 'label': 0, 'score': 0.6997583508491516}
# {'box': [373, 487, 451, 535], 'label': 0, 'score': 0.599189817905426}
# {'box': [817, 462, 892, 570], 'label': 0, 'score': 0.9327051043510437}
# {'box': [638, 233, 741, 314], 'label': 0, 'score': 0.8911871314048767}
# {'box': [497, 532, 577, 634], 'label': 0, 'score': 0.8905531167984009}
# {'box': [789, 669, 885, 754], 'label': 0, 'score': 0.8795138001441956}
# {'box': [124, 616, 209, 702], 'label': 0, 'score': 0.8621782660484314}
# {'box': [312, 471, 409, 552], 'label': 0, 'score': 0.8519644141197205}
# {'box': [360, 53, 449, 127], 'label': 0, 'score': 0.7427927255630493}
# {'box': [609, 42, 685, 148], 'label': 0, 'score': 0.6620540618896484}
# {'box': [787, 893, 903, 954], 'label': 0, 'score': 0.659808337688446}
# {'box': [844, 260, 915, 364], 'label': 0, 'score': 0.605165421962738}
# {'box': [657, 617, 754, 733], 'label': 0, 'score': 0.9662695527076721}
# {'box': [193, 372, 275, 475], 'label': 0, 'score': 0.9511415362358093}
# {'box': [324, 583, 425, 667], 'label': 0, 'score': 0.9189568758010864}
# {'box': [33, 497, 134, 601], 'label': 0, 'score': 0.8923161625862122}
# {'box': [196, 192, 265, 298], 'label': 0, 'score': 0.8364250659942627}
# {'box': [339, 814, 456, 884], 'label': 0, 'score': 0.5335268378257751}
# {'box': [138, 791, 206, 906], 'label': 0, 'score': 0.8823439478874207}
# {'box': [248, 376, 349, 435], 'label': 0, 'score': 0.8041041493415833}
# {'box': [427, 545, 531, 605], 'label': 0, 'score': 0.7888982892036438}
# {'box': [871, 888, 963, 986], 'label': 0, 'score': 0.7600830793380737}
# {'box': [579, 393, 678, 473], 'label': 0, 'score': 0.7304611206054688}
# {'box': [841, 573, 952, 636], 'label': 0, 'score': 0.7222625017166138}
# {'box': [331, 824, 440, 897], 'label': 0, 'score': 0.7207869291305542}
# {'box': [481, 719, 583, 780], 'label': 0, 'score': 0.6609529256820679}
# {'box': [807, 826, 885, 924], 'label': 0, 'score': 0.9710820913314819}
# {'box': [476, 115, 572, 195], 'label': 0, 'score': 0.8112357258796692}
# {'box': [674, 65, 761, 161], 'label': 0, 'score': 0.7628542184829712}
# {'box': [460, 760, 547, 847], 'label': 0, 'score': 0.6968496441841125}
# {'box': [229, 794, 329, 879], 'label': 0, 'score': 0.6018742322921753}
# {'box': [674, 47, 723, 126], 'label': 0, 'score': 0.6918704509735107}
# {'box': [720, 3, 788, 96], 'label': 0, 'score': 0.9304009079933167}
# {'box': [667, 46, 726, 148], 'label': 0, 'score': 0.908170759677887}
# {'box': [57, 618, 130, 730], 'label': 0, 'score': 0.8957810401916504}
# {'box': [379, 391, 459, 499], 'label': 0, 'score': 0.8922831416130066}
# {'box': [263, 3, 355, 92], 'label': 0, 'score': 0.8809081315994263}
# {'box': [576, 399, 646, 507], 'label': 0, 'score': 0.8580041527748108}
# {'box': [180, 402, 263, 482], 'label': 0, 'score': 0.8501456379890442}
# {'box': [437, 622, 553, 693], 'label': 0, 'score': 0.8385389447212219}
# {'box': [714, 275, 798, 386], 'label': 0, 'score': 0.830525815486908}
# {'box': [461, 45, 560, 120], 'label': 0, 'score': 0.8301242589950562}
# {'box': [31, 230, 99, 332], 'label': 0, 'score': 0.8261327147483826}
# {'box': [390, 797, 460, 903], 'label': 0, 'score': 0.8052107095718384}
# {'box': [894, 19, 957, 122], 'label': 0, 'score': 0.7953660488128662}
# {'box': [583, 752, 653, 866], 'label': 0, 'score': 0.7864947319030762}
# {'box': [664, 603, 731, 712], 'label': 0, 'score': 0.7467417120933533}
# {'box': [279, 598, 374, 678], 'label': 0, 'score': 0.7045817375183105}
# {'box': [796, 719, 880, 832], 'label': 0, 'score': 0.6914517879486084}
# {'box': [880, 905, 962, 986], 'label': 0, 'score': 0.6458200216293335}
# {'box': [556, 212, 649, 287], 'label': 0, 'score': 0.6171851754188538}
# {'box': [192, 816, 284, 893], 'label': 0, 'score': 0.5971094369888306}
# {'box': [166, 139, 241, 223], 'label': 0, 'score': 0.5476340055465698}
# {'box': [528, 15, 605, 118], 'label': 0, 'score': 0.8158881068229675}
# {'box': [711, 448, 791, 533], 'label': 0, 'score': 0.7900857329368591}
# {'box': [676, 646, 744, 754], 'label': 0, 'score': 0.7260481119155884}
# {'box': [669, 196, 743, 283], 'label': 0, 'score': 0.6899036765098572}
# {'box': [552, 526, 637, 613], 'label': 0, 'score': 0.6292766332626343}
# {'box': [310, 445, 404, 533], 'label': 0, 'score': 0.5428662300109863}
# {'box': [265, 625, 351, 715], 'label': 0, 'score': 0.5295643210411072}
# {'box': [813, 454, 898, 559], 'label': 0, 'score': 0.9305567741394043}
# {'box': [454, 596, 551, 669], 'label': 0, 'score': 0.838474452495575}
# {'box': [812, 832, 875, 934], 'label': 0, 'score': 0.8321478366851807}
# {'box': [726, 621, 793, 724], 'label': 0, 'score': 0.7935245037078857}
# {'box': [64, 758, 185, 831], 'label': 0, 'score': 0.7647771239280701}
# {'box': [595, 485, 681, 563], 'label': 0, 'score': 0.7417303919792175}
# {'box': [49, 98, 159, 163], 'label': 0, 'score': 0.7189165353775024}
# {'box': [619, 789, 717, 875], 'label': 0, 'score': 0.6654322743415833}
# {'box': [606, 196, 672, 299], 'label': 0, 'score': 0.6511014699935913}
# {'box': [453, 267, 533, 375], 'label': 0, 'score': 0.650407075881958}
# {'box': [312, 449, 383, 557], 'label': 0, 'score': 0.6286171674728394}
# {'box': [174, 319, 277, 386], 'label': 0, 'score': 0.5989930629730225}
# {'box': [61, 553, 159, 635], 'label': 0, 'score': 0.5797783732414246}
# {'box': [640, 47, 743, 131], 'label': 0, 'score': 0.5672320127487183}
# {'box': [663, 551, 717, 627], 'label': 0, 'score': 0.944499671459198}
# {'box': [220, 187, 275, 260], 'label': 0, 'score': 0.9351736903190613}
# {'box': [436, 19, 486, 94], 'label': 0, 'score': 0.8927509188652039}
# {'box': [856, 521, 908, 605], 'label': 0, 'score': 0.8485854268074036}
# {'box': [896, 288, 966, 343], 'label': 0, 'score': 0.8449473977088928}
# {'box': [759, 776, 817, 853], 'label': 0, 'score': 0.8181621432304382}
# {'box': [366, 419, 443, 474], 'label': 0, 'score': 0.7989816069602966}
# {'box': [678, 275, 754, 330], 'label': 0, 'score': 0.7747357487678528}
# {'box': [576, 739, 644, 815], 'label': 0, 'score': 0.7656071186065674}
# {'box': [263, 52, 332, 99], 'label': 0, 'score': 0.7631291747093201}
# {'box': [802, 55, 856, 131], 'label': 0, 'score': 0.7362753748893738}
# {'box': [409, 539, 465, 611], 'label': 0, 'score': 0.7314703464508057}
# {'box': [1, 849, 46, 927], 'label': 0, 'score': 0.7262384295463562}
# {'box': [2, 386, 52, 460], 'label': 0, 'score': 0.7239280939102173}
# {'box': [164, 880, 239, 938], 'label': 0, 'score': 0.657599151134491}
# {'box': [783, 324, 843, 389], 'label': 0, 'score': 0.6559287309646606}
# {'box': [294, 865, 368, 917], 'label': 0, 'score': 0.552869439125061}
# {'box': [370, 220, 436, 296], 'label': 0, 'score': 0.5446439981460571}
# {'box': [632, 138, 708, 200], 'label': 0, 'score': 0.5250585079193115}
# {'box': [120, 323, 207, 379], 'label': 0, 'score': 0.5180593729019165}
# {'box': [795, 783, 860, 858], 'label': 0, 'score': 0.9507574439048767}
# {'box': [821, 293, 919, 371], 'label': 0, 'score': 0.9133340716362}
# {'box': [409, 433, 477, 542], 'label': 0, 'score': 0.887728750705719}
# {'box': [590, 135, 647, 228], 'label': 0, 'score': 0.7330323457717896}
# {'box': [236, 288, 315, 393], 'label': 0, 'score': 0.6884878873825073}
# {'box': [712, 473, 806, 557], 'label': 0, 'score': 0.595435619354248}
# {'box': [911, 494, 987, 595], 'label': 0, 'score': 0.9305434226989746}
# {'box': [750, 427, 822, 536], 'label': 0, 'score': 0.9182742834091187}
# {'box': [796, 114, 897, 208], 'label': 0, 'score': 0.8737487196922302}
# {'box': [413, 839, 501, 921], 'label': 0, 'score': 0.8663750290870667}
# {'box': [44, 690, 143, 792], 'label': 0, 'score': 0.8632349967956543}
# {'box': [297, 151, 399, 226], 'label': 0, 'score': 0.8598036170005798}
# {'box': [5, 900, 109, 978], 'label': 0, 'score': 0.78507000207901}
# {'box': [586, 751, 682, 826], 'label': 0, 'score': 0.7810842990875244}
# {'box': [652, 13, 722, 117], 'label': 0, 'score': 0.7582032084465027}
# {'box': [221, 908, 333, 983], 'label': 0, 'score': 0.7549833655357361}
# {'box': [78, 215, 192, 292], 'label': 0, 'score': 0.7221930027008057}
# {'box': [482, 199, 582, 264], 'label': 0, 'score': 0.7157794237136841}
# {'box': [241, 343, 342, 433], 'label': 0, 'score': 0.7108001708984375}
# {'box': [23, 37, 121, 115], 'label': 0, 'score': 0.7105549573898315}
# {'box': [736, 849, 816, 956], 'label': 0, 'score': 0.6894504427909851}
# {'box': [644, 293, 752, 365], 'label': 0, 'score': 0.6816747188568115}
# {'box': [782, 604, 847, 711], 'label': 0, 'score': 0.5895852446556091}
# {'box': [849, 304, 959, 385], 'label': 0, 'score': 0.5624400973320007}
# {'box': [392, 567, 480, 670], 'label': 0, 'score': 0.5519407391548157}
# {'box': [188, 523, 302, 587], 'label': 0, 'score': 0.5320723056793213}
# {'box': [904, 825, 995, 909], 'label': 0, 'score': 0.5273029804229736}
# {'box': [149, 153, 249, 250], 'label': 0, 'score': 0.8666046261787415}
# {'box': [609, 669, 691, 788], 'label': 0, 'score': 0.8072951436042786}
# {'box': [213, 831, 283, 934], 'label': 0, 'score': 0.7981997728347778}
# {'box': [170, 637, 257, 732], 'label': 0, 'score': 0.7821411490440369}
# {'box': [381, 589, 443, 691], 'label': 0, 'score': 0.7635929584503174}
# {'box': [30, 341, 126, 423], 'label': 0, 'score': 0.7493278384208679}
# {'box': [725, 800, 794, 911], 'label': 0, 'score': 0.7191492915153503}
# {'box': [491, 851, 587, 917], 'label': 0, 'score': 0.7157970070838928}
# {'box': [826, 589, 926, 657], 'label': 0, 'score': 0.6756768822669983}
# {'box': [226, 425, 327, 487], 'label': 0, 'score': 0.6643639206886292}
# {'box': [896, 823, 977, 910], 'label': 0, 'score': 0.6632002592086792}
# {'box': [785, 357, 878, 428], 'label': 0, 'score': 0.6199101209640503}
# {'box': [412, 325, 475, 429], 'label': 0, 'score': 0.5973007082939148}
# {'box': [846, 92, 951, 165], 'label': 0, 'score': 0.544302225112915}
# {'box': [597, 482, 699, 550], 'label': 0, 'score': 0.5209462642669678}
# {'box': [580, 535, 633, 615], 'label': 0, 'score': 0.9204636812210083}
# {'box': [92, 377, 158, 461], 'label': 0, 'score': 0.8953047394752502}
# {'box': [786, 83, 858, 163], 'label': 0, 'score': 0.7880003452301025}
# {'box': [201, 125, 281, 196], 'label': 0, 'score': 0.7150149345397949}
# {'box': [59, 133, 133, 213], 'label': 0, 'score': 0.658426821231842}
# {'box': [32, 193, 147, 296], 'label': 0, 'score': 0.9301445484161377}
# {'box': [77, 69, 178, 131], 'label': 0, 'score': 0.8554808497428894}
# {'box': [425, 261, 533, 339], 'label': 0, 'score': 0.8462367653846741}
# {'box': [592, 106, 706, 189], 'label': 0, 'score': 0.7345011234283447}
# {'box': [241, 61, 330, 165], 'label': 0, 'score': 0.6450679302215576}
# {'box': [777, 71, 860, 130], 'label': 0, 'score': 0.9231820106506348}
# {'box': [556, 346, 657, 422], 'label': 0, 'score': 0.8679842948913574}
# {'box': [798, 608, 875, 716], 'label': 0, 'score': 0.7513535618782043}
# {'box': [144, 418, 236, 505], 'label': 0, 'score': 0.7410021424293518}
# {'box': [167, 4, 272, 58], 'label': 0, 'score': 0.7178968787193298}
# {'box': [10, 843, 113, 920], 'label': 0, 'score': 0.7020525336265564}
# {'box': [234, 892, 324, 960], 'label': 0, 'score': 0.6918518543243408}
# {'box': [558, 5, 669, 64], 'label': 0, 'score': 0.6862063407897949}
# {'box': [455, 640, 549, 710], 'label': 0, 'score': 0.6729167699813843}
# {'box': [266, 157, 334, 269], 'label': 0, 'score': 0.6711766719818115}
# {'box': [705, 448, 793, 544], 'label': 0, 'score': 0.6616547703742981}
# {'box': [315, 349, 416, 417], 'label': 0, 'score': 0.6265227198600769}
# {'box': [9, 539, 109, 628], 'label': 0, 'score': 0.6229650378227234}
# {'box': [402, 758, 469, 862], 'label': 0, 'score': 0.6097449064254761}
# {'box': [615, 562, 674, 667], 'label': 0, 'score': 0.5592591166496277}
# {'box': [828, 295, 914, 399], 'label': 0, 'score': 0.5385734438896179}
# {'box': [793, 805, 851, 901], 'label': 0, 'score': 0.5373941659927368}
# {'box': [260, 595, 349, 678], 'label': 0, 'score': 0.5362326502799988}
# {'box': [366, 696, 431, 777], 'label': 0, 'score': 0.9502176642417908}
# {'box': [129, 154, 194, 253], 'label': 0, 'score': 0.8614810705184937}
# {'box': [173, 450, 231, 538], 'label': 0, 'score': 0.786224365234375}
# {'box': [185, 306, 271, 368], 'label': 0, 'score': 0.6545017957687378}
# {'box': [392, 2, 479, 50], 'label': 0, 'score': 0.5669240951538086}
# {'box': [440, 809, 525, 906], 'label': 0, 'score': 0.8965363502502441}
# {'box': [641, 456, 753, 528], 'label': 0, 'score': 0.8729254007339478}
# {'box': [220, 20, 304, 112], 'label': 0, 'score': 0.8670218586921692}
# {'box': [600, 61, 712, 134], 'label': 0, 'score': 0.8644786477088928}
# {'box': [393, 12, 501, 82], 'label': 0, 'score': 0.8199058175086975}
# {'box': [858, 3, 960, 71], 'label': 0, 'score': 0.7956706881523132}
# {'box': [558, 651, 646, 740], 'label': 0, 'score': 0.7654529213905334}
# {'box': [798, 651, 908, 720], 'label': 0, 'score': 0.7582513689994812}
# {'box': [932, 842, 995, 951], 'label': 0, 'score': 0.754569411277771}
# {'box': [796, 191, 893, 267], 'label': 0, 'score': 0.7529025077819824}
# {'box': [306, 656, 428, 733], 'label': 0, 'score': 0.6643710732460022}
# {'box': [357, 183, 425, 270], 'label': 0, 'score': 0.6632250547409058}
# {'box': [528, 265, 632, 350], 'label': 0, 'score': 0.6626240015029907}
# {'box': [11, 157, 103, 220], 'label': 0, 'score': 0.6437521576881409}
# {'box': [290, 428, 355, 530], 'label': 0, 'score': 0.6184106469154358}
# {'box': [724, 850, 822, 927], 'label': 0, 'score': 0.5665714144706726}
# {'box': [787, 635, 883, 737], 'label': 0, 'score': 0.9532701969146729}
# {'box': [165, 240, 273, 316], 'label': 0, 'score': 0.8933185935020447}
# {'box': [24, 141, 96, 243], 'label': 0, 'score': 0.8856949210166931}
# {'box': [613, 78, 681, 190], 'label': 0, 'score': 0.803413450717926}
# {'box': [855, 38, 943, 140], 'label': 0, 'score': 0.8001561164855957}
# {'box': [648, 724, 741, 795], 'label': 0, 'score': 0.7957460880279541}
# {'box': [15, 571, 111, 651], 'label': 0, 'score': 0.7283424139022827}
# {'box': [414, 192, 503, 291], 'label': 0, 'score': 0.7001453638076782}
# {'box': [276, 923, 397, 987], 'label': 0, 'score': 0.6949931979179382}
# {'box': [738, 220, 854, 290], 'label': 0, 'score': 0.686048686504364}
# {'box': [286, 372, 354, 476], 'label': 0, 'score': 0.6794553995132446}
# {'box': [889, 369, 958, 471], 'label': 0, 'score': 0.665736734867096}
# {'box': [215, 601, 309, 673], 'label': 0, 'score': 0.6212493181228638}
# {'box': [1, 774, 102, 839], 'label': 0, 'score': 0.6163699626922607}
# {'box': [457, 846, 545, 925], 'label': 0, 'score': 0.6082645058631897}
# {'box': [585, 280, 692, 347], 'label': 0, 'score': 0.6062192916870117}
# {'box': [553, 527, 661, 611], 'label': 0, 'score': 0.5776011347770691}
# {'box': [738, 445, 801, 546], 'label': 0, 'score': 0.5221520066261292}
# {'box': [169, 876, 257, 975], 'label': 0, 'score': 0.9623545408248901}
# {'box': [867, 772, 951, 886], 'label': 0, 'score': 0.8264853358268738}
# {'box': [384, 853, 497, 923], 'label': 0, 'score': 0.7909862995147705}
# {'box': [820, 411, 935, 481], 'label': 0, 'score': 0.7854526042938232}
# {'box': [786, 219, 892, 289], 'label': 0, 'score': 0.6535419225692749}
# {'box': [231, 175, 315, 294], 'label': 0, 'score': 0.9856677055358887}
# ...
# {'box': [308, 497, 377, 546], 'label': 0, 'score': 0.7359796166419983}
# {'box': [629, 227, 709, 272], 'label': 0, 'score': 0.6845073103904724}
# {'box': [167, 502, 230, 570], 'label': 0, 'score': 0.6820752620697021}
# {'box': [276, 67, 352, 120], 'label': 0, 'score': 0.6783438920974731}
# {'box': [379, 751, 456, 800], 'label': 0, 'score': 0.6687694787979126}
# {'box': [77, 361, 156, 412], 'label': 0, 'score': 0.6657134890556335}
# {'box': [9, 811, 61, 875], 'label': 0, 'score': 0.6560049653053284}
# {'box': [695, 899, 774, 944], 'label': 0, 'score': 0.6241559982299805}
# {'box': [912, 852, 960, 930], 'label': 0, 'score': 0.6054238677024841}
# {'box': [430, 6, 493, 67], 'label': 0, 'score': 0.5829421281814575}
# {'box': [721, 694, 789, 744], 'label': 0, 'score': 0.5821846127510071}
# {'box': [499, 393, 560, 467], 'label': 0, 'score': 0.5482370257377625}
# {'box': [800, 298, 847, 362], 'label': 0, 'score': 0.5142592787742615}
# {'box': [317, 681, 399, 757], 'label': 0, 'score': 0.9573705196380615}
# {'box': [234, 164, 310, 251], 'label': 0, 'score': 0.9435806274414062}
# {'box': [612, 495, 715, 562], 'label': 0, 'score': 0.9284197092056274}
# {'box': [100, 630, 173, 728], 'label': 0, 'score': 0.7657641172409058}
# {'box': [212, 5, 304, 55], 'label': 0, 'score': 0.7574771046638489}
# {'box': [24, 874, 103, 956], 'label': 0, 'score': 0.9624671936035156}
# {'box': [898, 92, 975, 162], 'label': 0, 'score': 0.8723771572113037}
# {'box': [148, 925, 222, 994], 'label': 0, 'score': 0.8671791553497314}
# {'box': [310, 701, 369, 789], 'label': 0, 'score': 0.8346930742263794}
# {'box': [914, 929, 986, 995], 'label': 0, 'score': 0.8094214797019958}
# {'box': [222, 175, 274, 225], 'label': 0, 'score': 0.8039047122001648}
# {'box': [647, 900, 719, 990], 'label': 0, 'score': 0.7958621382713318}
# {'box': [366, 885, 446, 953], 'label': 0, 'score': 0.7855736613273621}
# {'box': [152, 694, 228, 772], 'label': 0, 'score': 0.7810752391815186}
# {'box': [826, 465, 905, 527], 'label': 0, 'score': 0.7514388561248779}
# {'box': [379, 171, 461, 238], 'label': 0, 'score': 0.7426291108131409}
# {'box': [179, 562, 262, 622], 'label': 0, 'score': 0.7311381101608276}
# {'box': [779, 684, 843, 771], 'label': 0, 'score': 0.7245193123817444}
# {'box': [764, 151, 816, 233], 'label': 0, 'score': 0.710719883441925}
# {'box': [523, 80, 600, 158], 'label': 0, 'score': 0.7094424366950989}
# {'box': [816, 313, 910, 366], 'label': 0, 'score': 0.7046984434127808}
# {'box': [221, 296, 281, 377], 'label': 0, 'score': 0.6724110245704651}
# {'box': [403, 563, 490, 616], 'label': 0, 'score': 0.6603075861930847}
# {'box': [7, 562, 64, 646], 'label': 0, 'score': 0.6572369933128357}
# {'box': [418, 306, 485, 394], 'label': 0, 'score': 0.6491590142250061}
# {'box': [687, 511, 772, 575], 'label': 0, 'score': 0.6375534534454346}
# {'box': [490, 892, 585, 948], 'label': 0, 'score': 0.6204061508178711}
# {'box': [872, 584, 932, 668], 'label': 0, 'score': 0.5734378099441528}
# {'box': [805, 839, 862, 927], 'label': 0, 'score': 0.5440777540206909}
# {'box': [128, 415, 196, 493], 'label': 0, 'score': 0.5395447611808777}
# {'box': [633, 747, 726, 827], 'label': 0, 'score': 0.5320184230804443}
# {'box': [559, 585, 653, 649], 'label': 0, 'score': 0.513494074344635}
# {'box': [183, 49, 265, 126], 'label': 0, 'score': 0.9376885890960693}
# {'box': [273, 934, 356, 995], 'label': 0, 'score': 0.9372808933258057}
# {'box': [3, 740, 56, 808], 'label': 0, 'score': 0.9249365925788879}
# {'box': [590, 61, 658, 147], 'label': 0, 'score': 0.8773055672645569}
# {'box': [544, 350, 631, 423], 'label': 0, 'score': 0.8714662790298462}
# {'box': [164, 737, 251, 798], 'label': 0, 'score': 0.8668400645256042}
# {'box': [134, 299, 207, 377], 'label': 0, 'score': 0.8579469323158264}
# {'box': [864, 822, 941, 887], 'label': 0, 'score': 0.8526644110679626}
# {'box': [490, 473, 539, 556], 'label': 0, 'score': 0.814849853515625}
# {'box': [734, 26, 822, 90], 'label': 0, 'score': 0.7967079281806946}
# {'box': [528, 745, 589, 834], 'label': 0, 'score': 0.7780840992927551}
# {'box': [720, 461, 778, 557], 'label': 0, 'score': 0.7198545932769775}
# {'box': [25, 150, 91, 230], 'label': 0, 'score': 0.7184396386146545}
# {'box': [630, 883, 721, 937], 'label': 0, 'score': 0.7180085182189941}
# {'box': [72, 872, 122, 951], 'label': 0, 'score': 0.7135328650474548}
# {'box': [392, 316, 459, 409], 'label': 0, 'score': 0.6888228058815002}
# {'box': [615, 631, 685, 707], 'label': 0, 'score': 0.6857004165649414}
# {'box': [790, 319, 859, 411], 'label': 0, 'score': 0.6806954145431519}
# {'box': [655, 194, 710, 287], 'label': 0, 'score': 0.6796790957450867}
# {'box': [450, 612, 510, 707], 'label': 0, 'score': 0.6609323620796204}
# {'box': [798, 618, 854, 705], 'label': 0, 'score': 0.6484003663063049}
# {'box': [886, 54, 938, 145], 'label': 0, 'score': 0.6461917757987976}
# {'box': [302, 499, 368, 590], 'label': 0, 'score': 0.631527304649353}
# {'box': [37, 462, 134, 517], 'label': 0, 'score': 0.5985962152481079}
# {'box': [347, 773, 412, 841], 'label': 0, 'score': 0.5949878692626953}
# {'box': [498, 192, 568, 267], 'label': 0, 'score': 0.5122689604759216}
# {'box': [488, 91, 568, 203], 'label': 0, 'score': 0.9886904954910278}
# {'box': [46, 84, 119, 201], 'label': 0, 'score': 0.9233176112174988}
# {'box': [705, 876, 801, 976], 'label': 0, 'score': 0.8998695015907288}
# {'box': [500, 759, 596, 866], 'label': 0, 'score': 0.8753058910369873}
# {'box': [156, 734, 270, 800], 'label': 0, 'score': 0.8677148222923279}
# {'box': [159, 503, 238, 611], 'label': 0, 'score': 0.8545921444892883}
# {'box': [835, 752, 902, 851], 'label': 0, 'score': 0.8331965804100037}
# {'box': [365, 450, 455, 542], 'label': 0, 'score': 0.8245441317558289}
# {'box': [52, 328, 153, 430], 'label': 0, 'score': 0.8009049296379089}
# {'box': [817, 458, 912, 550], 'label': 0, 'score': 0.769098699092865}
# {'box': [353, 703, 434, 797], 'label': 0, 'score': 0.7235192060470581}
# {'box': [917, 89, 983, 179], 'label': 0, 'score': 0.7201510071754456}
# {'box': [520, 400, 633, 478], 'label': 0, 'score': 0.695436954498291}
# {'box': [282, 941, 374, 994], 'label': 0, 'score': 0.6894485950469971}
# {'box': [553, 559, 627, 659], 'label': 0, 'score': 0.6036249995231628}
# {'box': [3, 699, 83, 756], 'label': 0, 'score': 0.5308550596237183}
# {'box': [39, 364, 105, 451], 'label': 0, 'score': 0.9094818830490112}
# {'box': [69, 753, 127, 848], 'label': 0, 'score': 0.8852745890617371}
# {'box': [595, 221, 669, 305], 'label': 0, 'score': 0.8419103622436523}
# {'box': [479, 632, 548, 720], 'label': 0, 'score': 0.8330638408660889}
# {'box': [503, 94, 556, 181], 'label': 0, 'score': 0.8140705823898315}
# {'box': [345, 481, 417, 566], 'label': 0, 'score': 0.8019387125968933}
# {'box': [196, 20, 248, 102], 'label': 0, 'score': 0.7956894040107727}
# {'box': [855, 130, 920, 223], 'label': 0, 'score': 0.7920507788658142}
# {'box': [376, 831, 437, 922], 'label': 0, 'score': 0.7887383699417114}
# {'box': [692, 96, 749, 182], 'label': 0, 'score': 0.7420135736465454}
# {'box': [829, 300, 920, 364], 'label': 0, 'score': 0.7183805108070374}
# {'box': [531, 422, 604, 495], 'label': 0, 'score': 0.7159218192100525}
# {'box': [288, 635, 376, 694], 'label': 0, 'score': 0.6867249608039856}
# {'box': [410, 231, 469, 313], 'label': 0, 'score': 0.675629198551178}
# {'box': [299, 349, 374, 400], 'label': 0, 'score': 0.6699960231781006}
# {'box': [149, 206, 224, 288], 'label': 0, 'score': 0.6433750987052917}
# {'box': [165, 449, 251, 501], 'label': 0, 'score': 0.6183600425720215}
# {'box': [719, 737, 783, 821], 'label': 0, 'score': 0.5938088297843933}
# {'box': [552, 791, 646, 858], 'label': 0, 'score': 0.5255940556526184}
# {'box': [289, 151, 366, 199], 'label': 0, 'score': 0.5242253541946411}
# {'box': [897, 817, 975, 884], 'label': 0, 'score': 0.922882616519928}
# {'box': [561, 619, 624, 716], 'label': 0, 'score': 0.8853691816329956}
# {'box': [468, 30, 551, 96], 'label': 0, 'score': 0.836455762386322}
# {'box': [633, 347, 702, 426], 'label': 0, 'score': 0.8240444660186768}
# {'box': [565, 782, 624, 872], 'label': 0, 'score': 0.796730637550354}
# {'box': [809, 924, 900, 990], 'label': 0, 'score': 0.7888379096984863}
# {'box': [784, 6, 858, 84], 'label': 0, 'score': 0.7857664227485657}
# {'box': [474, 204, 556, 290], 'label': 0, 'score': 0.7832040786743164}
# {'box': [810, 463, 867, 553], 'label': 0, 'score': 0.7705334424972534}
# {'box': [255, 244, 308, 324], 'label': 0, 'score': 0.7587306499481201}
# {'box': [391, 556, 474, 624], 'label': 0, 'score': 0.7192676067352295}
# {'box': [74, 740, 153, 810], 'label': 0, 'score': 0.7141245007514954}
# {'box': [355, 123, 410, 214], 'label': 0, 'score': 0.6941233277320862}
# {'box': [234, 722, 327, 774], 'label': 0, 'score': 0.6828901171684265}
# {'box': [663, 880, 738, 954], 'label': 0, 'score': 0.6797258853912354}
# {'box': [216, 840, 286, 919], 'label': 0, 'score': 0.6768224835395813}
# {'box': [675, 202, 763, 274], 'label': 0, 'score': 0.6722778081893921}
# {'box': [887, 580, 976, 636], 'label': 0, 'score': 0.6669269800186157}
# {'box': [655, 518, 734, 573], 'label': 0, 'score': 0.614700436592102}
# {'box': [248, 552, 320, 635], 'label': 0, 'score': 0.6023154258728027}
# {'box': [379, 336, 462, 404], 'label': 0, 'score': 0.5829575657844543}
# {'box': [630, 58, 725, 106], 'label': 0, 'score': 0.5599886775016785}
# {'box': [213, 86, 281, 177], 'label': 0, 'score': 0.5517550110816956}
# {'box': [776, 317, 849, 395], 'label': 0, 'score': 0.5149511694908142}
# {'box': [88, 130, 146, 221], 'label': 0, 'score': 0.5137075781822205}
# {'box': [122, 622, 183, 708], 'label': 0, 'score': 0.5063555240631104}
# {'box': [217, 412, 308, 466], 'label': 0, 'score': 0.5027621984481812}
# {'box': [757, 335, 815, 408], 'label': 0, 'score': 0.907971203327179}
# {'box': [558, 504, 613, 575], 'label': 0, 'score': 0.875956118106842}
# {'box': [645, 865, 697, 925], 'label': 0, 'score': 0.8729045987129211}
# {'box': [10, 421, 61, 492], 'label': 0, 'score': 0.850649893283844}
# {'box': [243, 19, 290, 92], 'label': 0, 'score': 0.8351582884788513}
# {'box': [348, 73, 413, 128], 'label': 0, 'score': 0.8180126547813416}
# {'box': [943, 756, 986, 826], 'label': 0, 'score': 0.7752534747123718}
# {'box': [186, 273, 247, 320], 'label': 0, 'score': 0.76801598072052}
# {'box': [864, 386, 921, 468], 'label': 0, 'score': 0.7542722821235657}
# {'box': [543, 226, 626, 280], 'label': 0, 'score': 0.7452312707901001}
# {'box': [590, 320, 655, 384], 'label': 0, 'score': 0.7299715280532837}
# {'box': [444, 479, 512, 521], 'label': 0, 'score': 0.7047904133796692}
# {'box': [456, 146, 508, 219], 'label': 0, 'score': 0.7020286917686462}
# {'box': [716, 566, 770, 634], 'label': 0, 'score': 0.6461991667747498}
# {'box': [189, 834, 241, 913], 'label': 0, 'score': 0.626815676689148}
# {'box': [207, 632, 253, 698], 'label': 0, 'score': 0.6200414896011353}
# {'box': [156, 514, 220, 601], 'label': 0, 'score': 0.6132299900054932}
# {'box': [310, 711, 363, 783], 'label': 0, 'score': 0.5957244634628296}
# {'box': [879, 515, 940, 583], 'label': 0, 'score': 0.5926933884620667}
# {'box': [820, 694, 871, 774], 'label': 0, 'score': 0.5472654700279236}
# {'box': [569, 663, 632, 718], 'label': 0, 'score': 0.5373115539550781}
# {'box': [786, 72, 859, 122], 'label': 0, 'score': 0.517487645149231}
# {'box': [917, 860, 992, 942], 'label': 0, 'score': 0.898685872554779}
# {'box': [453, 730, 537, 783], 'label': 0, 'score': 0.868787407875061}
# {'box': [618, 747, 696, 831], 'label': 0, 'score': 0.8685041666030884}
# {'box': [552, 921, 646, 976], 'label': 0, 'score': 0.7730085849761963}
# {'box': [900, 564, 975, 636], 'label': 0, 'score': 0.7348994016647339}
# {'box': [753, 804, 825, 894], 'label': 0, 'score': 0.6581381559371948}
# {'box': [861, 703, 920, 788], 'label': 0, 'score': 0.6475459933280945}
# {'box': [794, 350, 885, 409], 'label': 0, 'score': 0.6312198042869568}
# {'box': [328, 899, 419, 961], 'label': 0, 'score': 0.8383865356445312}
# {'box': [530, 424, 615, 520], 'label': 0, 'score': 0.8236882090568542}
# {'box': [329, 291, 428, 363], 'label': 0, 'score': 0.8201361298561096}
# {'box': [108, 771, 197, 850], 'label': 0, 'score': 0.8034714460372925}
# {'box': [808, 299, 875, 394], 'label': 0, 'score': 0.8006170988082886}
# {'box': [639, 867, 729, 951], 'label': 0, 'score': 0.7945502400398254}
# {'box': [699, 494, 784, 561], 'label': 0, 'score': 0.7685789465904236}
# {'box': [377, 419, 469, 475], 'label': 0, 'score': 0.7423079013824463}
# {'box': [78, 487, 143, 561], 'label': 0, 'score': 0.739690899848938}
# {'box': [789, 602, 874, 670], 'label': 0, 'score': 0.7268651723861694}
# {'box': [924, 855, 984, 946], 'label': 0, 'score': 0.7144070863723755}
# {'box': [484, 773, 549, 860], 'label': 0, 'score': 0.6738405227661133}
# {'box': [679, 141, 757, 206], 'label': 0, 'score': 0.6615646481513977}
# {'box': [62, 341, 135, 424], 'label': 0, 'score': 0.6513274908065796}
# {'box': [303, 40, 402, 96], 'label': 0, 'score': 0.6080530285835266}
# {'box': [174, 612, 263, 673], 'label': 0, 'score': 0.5277510285377502}
# {'box': [464, 86, 547, 179], 'label': 0, 'score': 0.521899402141571}
# {'box': [226, 411, 285, 495], 'label': 0, 'score': 0.5163723230361938}
# {'box': [571, 26, 673, 85], 'label': 0, 'score': 0.5041230320930481}
# {'box': [657, 594, 711, 670], 'label': 0, 'score': 0.9644966125488281}
# {'box': [129, 828, 195, 911], 'label': 0, 'score': 0.9282621145248413}
# {'box': [204, 665, 262, 745], 'label': 0, 'score': 0.8516396284103394}
# {'box': [93, 34, 172, 108], 'label': 0, 'score': 0.8320168852806091}
# {'box': [689, 832, 767, 905], 'label': 0, 'score': 0.8300890922546387}
# {'box': [760, 432, 847, 489], 'label': 0, 'score': 0.7795081734657288}
# {'box': [27, 163, 110, 245], 'label': 0, 'score': 0.7644580602645874}
# {'box': [137, 393, 206, 481], 'label': 0, 'score': 0.7169209122657776}
# {'box': [170, 273, 250, 335], 'label': 0, 'score': 0.6836695671081543}
# {'box': [898, 279, 957, 384], 'label': 0, 'score': 0.6762465834617615}
# {'box': [372, 243, 448, 319], 'label': 0, 'score': 0.6634464859962463}
# {'box': [684, 225, 761, 302], 'label': 0, 'score': 0.6130018830299377}
# {'box': [586, 433, 672, 500], 'label': 0, 'score': 0.5532543063163757}
# {'box': [907, 505, 986, 590], 'label': 0, 'score': 0.5406906008720398}
# {'box': [304, 605, 394, 662], 'label': 0, 'score': 0.5062685608863831}
# {'box': [509, 87, 566, 180], 'label': 0, 'score': 0.8453215956687927}
# {'box': [619, 220, 679, 313], 'label': 0, 'score': 0.8266971707344055}
# {'box': [500, 586, 561, 667], 'label': 0, 'score': 0.8094040751457214}
# {'box': [686, 673, 757, 752], 'label': 0, 'score': 0.7762459516525269}
# {'box': [822, 516, 890, 596], 'label': 0, 'score': 0.7749060392379761}
# {'box': [562, 701, 620, 791], 'label': 0, 'score': 0.7699481844902039}
# {'box': [634, 45, 720, 103], 'label': 0, 'score': 0.7607378363609314}
# {'box': [401, 831, 490, 896], 'label': 0, 'score': 0.7520622611045837}
# {'box': [754, 151, 811, 239], 'label': 0, 'score': 0.7488452792167664}
# {'box': [685, 479, 763, 555], 'label': 0, 'score': 0.7369813919067383}
# {'box': [836, 683, 922, 743], 'label': 0, 'score': 0.7299203276634216}
# {'box': [346, 939, 432, 990], 'label': 0, 'score': 0.7144767045974731}
# {'box': [785, 844, 873, 899], 'label': 0, 'score': 0.7031465172767639}
# {'box': [259, 406, 317, 495], 'label': 0, 'score': 0.6842400431632996}
# {'box': [456, 279, 518, 371], 'label': 0, 'score': 0.6564281582832336}
# {'box': [334, 146, 421, 217], 'label': 0, 'score': 0.6494360566139221}
# {'box': [614, 837, 678, 916], 'label': 0, 'score': 0.6470161080360413}
# {'box': [588, 428, 640, 519], 'label': 0, 'score': 0.6465682983398438}
# {'box': [116, 740, 196, 811], 'label': 0, 'score': 0.6445359587669373}
# {'box': [402, 450, 483, 524], 'label': 0, 'score': 0.639396071434021}
# {'box': [841, 296, 926, 353], 'label': 0, 'score': 0.6304944157600403}
# {'box': [781, 1, 836, 75], 'label': 0, 'score': 0.6095752120018005}
# {'box': [219, 611, 291, 695], 'label': 0, 'score': 0.6074711680412292}
# {'box': [889, 114, 958, 200], 'label': 0, 'score': 0.6046174764633179}
# {'box': [110, 442, 201, 496], 'label': 0, 'score': 0.5893672704696655}
# {'box': [3, 209, 88, 287], 'label': 0, 'score': 0.5413557887077332}
# {'box': [234, 796, 329, 869], 'label': 0, 'score': 0.5349133610725403}
# {'box': [365, 677, 458, 729], 'label': 0, 'score': 0.5049832463264465}

# %%
# ingest back in the coordinates of detections within an image referenced by their filename

with open('mosaics/tiles/data_bubble.json') as f:
    img_data = json.load(f)

# open the satellite image
dataset = rasterio.open(infile)
    
geolocated_annotations = []
for annotation in image_annotations:
    for detection in annotation[1]:
        try:            
            local_bounding_box = np.array([[detection[0], detection[1]], [detection[2], detection[1]], [detection[2], detection[3]], [detection[0], detection[3]]]).astype(int)
            image_located_bb = local_bounding_box + [img_data["image_locations"][annotation[0]]]

            geolocated_bb = []
            for point in image_located_bb:
                geolocated_bb.append(dataset.transform * point)
            geolocated_annotations.append(geolocated_bb)
        except ValueError: # if the image doesn't have a detection
            pass
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-8-c3cc31fc7b81> in <module>
#      12         try:
#      13             local_bounding_box = np.array([[detection[0], detection[1]], [detection[2], detection[1]], [detection[2], detection[3]], [detection[0], detection[3]]]).astype(int)
# ---> 14             image_located_bb = local_bounding_box + [img_data["image_locations"][annotation[0]]]
#      15
#      16             geolocated_bb = []
#
# KeyError: 'SteepleJason_Hump_Nov2019_transparent_mosaic_group1---232.png'

# %%
# ingest back in the coordinates of detections within an image referenced by their filename

with open('mosaics/tiles/data_hump.json') as f:
    img_data_hump = json.load(f)

# open the satellite image
dataset_hump = rasterio.open(infile_hump)
    
geolocated_annotations_hump = []
for annotation in image_annotations:
    for detection in annotation[1]:
        try:            
            local_bounding_box = np.array([[detection[0], detection[1]], [detection[2], detection[1]], [detection[2], detection[3]], [detection[0], detection[3]]]).astype(int)
            image_located_bb = local_bounding_box + [img_data_hump["image_locations"][annotation[0]]]

            geolocated_bb = []
            for point in image_located_bb:
                geolocated_bb.append(dataset_hump.transform * point)
            geolocated_annotations_hump.append(geolocated_bb)
        except ValueError: # if the image doesn't have a detection
            pass

# %%
#geolocated_annotations = geolocated_annotations_bubble + geolocated_annotations_hump
len(geolocated_annotations_bubble)
len(geolocated_annotations_hump)

# %%
# write out the detections as a shapefile

from collections import OrderedDict
import fiona
from fiona.crs import from_epsg

# Define your schema as a polygon geom with a couple of fields
schema = {
    'geometry': 'Polygon',
    'properties': OrderedDict([
        ('ImageName', 'str'),
        ('Detection', 'str')
  ])
}

with fiona.open(
    'albatross_detections1.shp',
    'w',
    driver='ESRI Shapefile',
    crs=dataset.crs,
    schema=schema) as c:
    
    for num, polygon in enumerate(geolocated_annotations_bubble):
        record = {
            'geometry': {'coordinates': [polygon], 'type': 'Polygon'},
            'id': num,
            'properties': OrderedDict([('ImageName', infile),
                                       ('Detection', 'Albatross')
                                       ]),
            'type': 'Feature'}
        c.write(record)

# %%
# write out the detections as a shapefile

from collections import OrderedDict
import fiona
from fiona.crs import from_epsg

# Define your schema as a polygon geom with a couple of fields
schema = {
    'geometry': 'Polygon',
    'properties': OrderedDict([
        ('ImageName', 'str'),
        ('Detection', 'str')
  ])
}

with fiona.open(
    'albatross_detections2.shp',
    'w',
    driver='ESRI Shapefile',
    crs=dataset.crs,
    schema=schema) as c:
    
    for num, polygon in enumerate(geolocated_annotations_hump):
        record = {
            'geometry': {'coordinates': [polygon], 'type': 'Polygon'},
            'id': num,
            'properties': OrderedDict([('ImageName', infile),
                                       ('Detection', 'Albatross')
                                       ]),
            'type': 'Feature'}
        c.write(record)

# %%
# add the new detections to the old via_region_data.json file

#"11_fiX1mEhK","[""2015_02_02_hay_island_flight03_s110rgb_jpeg_mosaic_group1---27.png""]",0,"[]","[2,509.275,929.174,89.376,48.904]","{}"

#for filepath, detections in detected_labels.items():
    #fn = filepath.split("/")[-1]
    # TODO is deep copy correct?
    #for filename_size, metadata in existing_labels.items():
        #if fn == metadata["filename"]:
            #for detection in detections:
                # 'box' : [x1, y1, x2, y2]
                #x1 = detection["box"][0]
                #y1 = detection["box"][1]
                #x2 = detection["box"][2]
                #y2 = detection["box"][3]
                #print(x1,x2,y1,y2)
                #metadata["regions"].append({'shape_attributes': {'name': 'rect', 'x': x1, 'y': y1, 'width': x2-x1, 'height': y2-y1}, 'region_attributes': {}})

# %%
# write out new VIA file with additional detections

#with open(img_dir + '/via_region_data_detections.json', 'w') as fp:
    #json.dump(existing_labels, fp)
