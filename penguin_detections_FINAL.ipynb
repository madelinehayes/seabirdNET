# %%
! ../keras-retinanet/keras_retinanet/bin/train.py --weights data/resnet50_coco_best_v2.1.0.h5 \
--batch-size 2 --steps 500 --epochs 30 \
--snapshot-path data/snapshots_penguin/noresize \
--random-transform \
--config config_penguin/config.ini \
csv data/mosaics/labeled_tiles_penguin/train_annotations_final.csv data/mosaics/labeled_tiles_penguin/classes.csv \
--val-annotations data/mosaics/labeled_tiles_penguin/val_annotations_final.csv
# Out:
# Using TensorFlow backend.
# 2020-05-26 16:26:39.704987: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libnvinfer.so.6
# 2020-05-26 16:26:39.748167: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libnvinfer_plugin.so.6
# COMET INFO: old comet version (3.1.4) detected. current: 3.1.8 please update your comet lib with command: `pip install --no-cache-dir --upgrade comet_ml`
# COMET WARNING: Failing to collect the installed os packages
# COMET INFO: Experiment is live on comet.ml https://www.comet.ml/madelinehayes/steeple-jason/30ebd398a8f140c29006f4975fe9ce5c
#
# Creating model, this may take a second...
# 2020-05-26 16:26:43.961047: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcuda.so.1
# ...

# %%
! ../keras-retinanet/keras_retinanet/bin/convert_model.py --config config_penguin/config.ini data/snapshots_penguin/noresize/resnet50_csv_30.h5 data/snapshots_penguin/noresize/final_model_penguin_noresize.h5
# Out:
# Using TensorFlow backend.
# 2020-05-26 17:11:56.592472: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libnvinfer.so.6
# 2020-05-26 17:11:56.597752: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libnvinfer_plugin.so.6
# 2020-05-26 17:11:57.632048: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcuda.so.1
# 2020-05-26 17:11:57.646321: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-05-26 17:11:57.646668: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1555] Found device 0 with properties:
# pciBusID: 0000:01:00.0 name: GeForce GTX 1060 computeCapability: 6.1
# coreClock: 1.6705GHz coreCount: 10 deviceMemorySize: 5.94GiB deviceMemoryBandwidth: 178.99GiB/s
# ...

# %%
! ../keras-retinanet/keras_retinanet/bin/evaluate.py --config config_penguin/config.ini csv data/mosaics/labeled_tiles_penguin/test_annotations_final.csv data/mosaics/labeled_tiles_penguin/classes.csv data/snapshots_penguin/noresize/final_model_penguin_noresize.h5
# Out:
# Using TensorFlow backend.
# 2020-05-26 17:12:38.754960: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libnvinfer.so.6
# 2020-05-26 17:12:38.756070: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libnvinfer_plugin.so.6
# Loading model, this may take a second...
# 2020-05-26 17:12:39.593604: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcuda.so.1
# 2020-05-26 17:12:39.601795: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-05-26 17:12:39.602053: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1555] Found device 0 with properties:
# pciBusID: 0000:01:00.0 name: GeForce GTX 1060 computeCapability: 6.1
# ...

# %%
! ../keras-retinanet/keras_retinanet/bin/evaluate.py --config config_penguin/config.ini csv data/mosaics/labeled_tiles_penguin/val_annotations_final.csv data/mosaics/labeled_tiles_penguin/classes.csv data/snapshots_penguin/noresize/final_model_penguin_noresize.h5
# Out:
# Using TensorFlow backend.
# 2020-05-26 17:13:19.220671: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libnvinfer.so.6
# 2020-05-26 17:13:19.221753: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libnvinfer_plugin.so.6
# Loading model, this may take a second...
# 2020-05-26 17:13:20.011373: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcuda.so.1
# 2020-05-26 17:13:20.027476: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-05-26 17:13:20.028023: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1555] Found device 0 with properties:
# pciBusID: 0000:01:00.0 name: GeForce GTX 1060 computeCapability: 6.1
# ...

# %%
# %matplotlib inline

# %reload_ext autoreload
# %autoreload 2

import keras

from keras_retinanet.models import retinanet
from keras_retinanet import models
from keras_retinanet.utils.image import read_image_bgr, preprocess_image, resize_image
from keras_retinanet.utils.visualization import draw_box, draw_caption
from keras_retinanet.utils.colors import label_color

import matplotlib.pyplot as plt
import cv2
import os
import numpy as np
import time
import json
from random import shuffle

import tensorflow as tf

def get_session():
    config = tf.compat.v1.ConfigProto()
    config.gpu_options.allow_growth = True
    return tf.compat.v1.Session(config=config)

tf.compat.v1.keras.backend.set_session(get_session())
# Out:
# Using TensorFlow backend.

# %%
model_path = 'data/snapshots_penguin/final/final_model_penguin_nms5.h5'

print(model_path)

model = models.load_model(model_path, backbone_name='resnet50')

print(model.summary())

labels_to_names = {0: 'penguin'}
# Out:
# data/snapshots_penguin/final/final_model_penguin_nms5.h5
# tracking <tf.Variable 'Variable:0' shape=(9, 4) dtype=float32, numpy=
# array([[ -8.087312 ,  -5.7986026,   8.087312 ,   5.7986026],
#        [-20.104906 , -14.415217 ,  20.104906 ,  14.415217 ],
#        [-25.698    , -18.425467 ,  25.698    ,  18.425467 ],
#        [ -6.848    ,  -6.848    ,   6.848    ,   6.848    ],
#        [-17.024    , -17.024    ,  17.024    ,  17.024    ],
#        [-21.76     , -21.76     ,  21.76     ,  21.76     ],
#        [ -5.7959023,  -8.09108  ,   5.7959023,   8.09108  ],
#        [-14.4085045, -20.114273 ,  14.4085045,  20.114273 ],
#        [-18.416885 , -25.709972 ,  18.416885 ,  25.709972 ]],
#       dtype=float32)> anchors
# tracking <tf.Variable 'Variable:0' shape=(9, 4) dtype=float32, numpy=
# array([[-16.174623 , -11.597205 ,  16.174623 ,  11.597205 ],
#        [-40.209812 , -28.830435 ,  40.209812 ,  28.830435 ],
#        [-51.396    , -36.850933 ,  51.396    ,  36.850933 ],
# ...

# %%
image_dir = "data/mosaics/GrandJason_SWLeftThird_Nov2019_transparent_mosaic_group1_250x250_overlap20/"

image_list = []
for root, dirs, files in os.walk(image_dir):
    for filename in files:
        if filename.lower().endswith(('.png')):
            image_list.append(image_dir + filename)
print(len(image_list))
# Out:
# 24255

# %%
visualize = True
min_score = 0.5

detections = {}

total_time = 0

count = 0
detection_iterations = 10
shuffle(image_list)

for image_path in image_list: 
    if count > detection_iterations:
        break
    else: 
        count +=1
    
    image = read_image_bgr(image_path)
    
    if visualize:
        draw = image.copy()
        draw = cv2.cvtColor(draw, cv2.COLOR_BGR2RGB)
        
    image = preprocess_image(image)
    image, scale = resize_image(image)
    
    start = time.time()
    boxes, scores, labels = model.predict_on_batch(np.expand_dims(image, axis=0))
    total_time += time.time() - start 
    
    boxes /= scale
    if any(score >= min_score for score in scores [0]):
        detections[image_path] = []
        
    for box, score, label in zip(boxes[0], scores[0], labels[0]):
        if score < min_score:
            break
            
        b = box.astype(int)
        detections[image_path].append({"box" : b, "label" : label, "score" : score})
        
        if visualize: 
            color = label_color(label)
            
            draw_box(draw, b, color=color)
            
            caption = "{} {:.3f}".format(labels_to_names[label], score)
            draw_caption(draw, b, caption)
            
    if any(score >= min_score for score in scores[0]):
        if visualize:
            plt.figure(figsize=(10, 10))
            plt.axis('off')
            plt.imshow(draw)
            plt.show()
            
print("Finished, time per image:", total_time/len(image_list))
# Out:
# Finished, time per image: 0.00025791008185907825

# %%
min_score = 0.5

detections = {}

total_time = 0

for image_path in image_list:
    
    image = read_image_bgr(image_path)
          
    image = preprocess_image(image)
    image, scale = resize_image(image)
    
    start = time.time()
    boxes, scores, labels = model.predict_on_batch(np.expand_dims(image, axis=0))
    total_time += time.time() - start
    
    boxes /= scale 
        
    if any(score >= min_score for score in scores[0]):
        detections[image_path] = []
    
    #boxes = non_max_suppression_fast(boxes[0], 0.1)
    
    for box, score, label in zip(boxes[0], scores[0], labels[0]):
        if score < min_score:
            break
        
        b = box.astype(int)    
        #pick = non_max_suppression_fast(boxes, 0.3)
        detections[image_path].append({"box" : b, "label" : label, "score" : score})
        
            
print("Finished, time per image:", total_time/len(image_list))
# Out:
# Finished, time per image: 0.12344436928602229

# %%
class MyEncoder(json.JSONEncoder):
    def default(self, obj):
        if isinstance(obj, np.integer):
            return int(obj)
        elif isinstance(obj, np.floating):
            return float(obj)
        elif isinstance(obj, np.ndarray):
            return obj.tolist()
        else:
            return super(MyEncoder, self).default(obj)

# %%
with open('data/detections_penguin/final/overlap20/detections_grandjason_swleftthird_250x250_overlap20.json', 'w') as fp:
    json.dump(detections, fp, cls=MyEncoder)
