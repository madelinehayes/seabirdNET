# %%
! ../keras-retinanet/keras_retinanet/bin/train.py --weights data/resnet50_coco_best_v2.1.0.h5 \
--batch-size 2 --steps 500 --epochs 30 \
--snapshot-path data/snapshots_penguin \
--random-transform \
--config config_penguin/config.ini \
csv data/mosaics/penguin/labeled_tiles_penguin/penguin_train_annotations_final.csv data/mosaics/penguin/labeled_tiles_penguin/classes.csv \
--val-annotations data/mosaics/penguin/labeled_tiles_penguin/penguin_val_annotations_final.csv
# Out:
# Using TensorFlow backend.
# 2020-07-14 18:38:06.426360: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libnvinfer.so.6
# 2020-07-14 18:38:06.462926: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libnvinfer_plugin.so.6
# COMET INFO: old comet version (3.1.8) detected. current: 3.1.12 please update your comet lib with command: `pip install --no-cache-dir --upgrade comet_ml`
# COMET INFO: Experiment is live on comet.ml https://www.comet.ml/madelinehayes/steeple-jason/362b60d3e3c948ffa61daf275b3047bb
#
# Creating model, this may take a second...
# 2020-07-14 18:38:14.213302: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcuda.so.1
# ...

# %%
! ../keras-retinanet/keras_retinanet/bin/convert_model.py --config config_penguin/config.ini data/snapshots_penguin/resnet50_csv_21.h5 data/snapshots_penguin/final/final_model_penguin.h5
# Out:
# Using TensorFlow backend.
# 2020-07-14 21:49:50.565688: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libnvinfer.so.6
# 2020-07-14 21:49:50.570511: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libnvinfer_plugin.so.6
# 2020-07-14 21:49:51.677068: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcuda.so.1
# 2020-07-14 21:49:51.688741: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-07-14 21:49:51.689070: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1555] Found device 0 with properties:
# pciBusID: 0000:01:00.0 name: GeForce GTX 1060 computeCapability: 6.1
# coreClock: 1.6705GHz coreCount: 10 deviceMemorySize: 5.94GiB deviceMemoryBandwidth: 178.99GiB/s
# ...

# %%
! ../keras-retinanet/keras_retinanet/bin/evaluate.py --config config_penguin/config.ini csv data/mosaics/penguin/labeled_tiles_penguin/penguin_test_annotations_final.csv data/mosaics/penguin/labeled_tiles_penguin/classes.csv data/snapshots_penguin/final_model_penguin.h5
# Out:
# Using TensorFlow backend.
# 2020-07-14 21:50:01.961505: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libnvinfer.so.6
# 2020-07-14 21:50:01.962612: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libnvinfer_plugin.so.6
# Loading model, this may take a second...
# 2020-07-14 21:50:02.885375: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcuda.so.1
# 2020-07-14 21:50:02.894276: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-07-14 21:50:02.894531: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1555] Found device 0 with properties:
# pciBusID: 0000:01:00.0 name: GeForce GTX 1060 computeCapability: 6.1
# ...

# %%
! ../keras-retinanet/keras_retinanet/bin/evaluate.py --config config_penguin/config.ini csv data/mosaics/penguin/labeled_tiles_penguin/penguin_val_annotations_final.csv data/mosaics/penguin/labeled_tiles_penguin/classes.csv data/snapshots_penguin/final_model_penguin.h5
# Out:
# Using TensorFlow backend.
# 2020-07-14 21:51:03.625352: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libnvinfer.so.6
# 2020-07-14 21:51:03.626443: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libnvinfer_plugin.so.6
# Loading model, this may take a second...
# 2020-07-14 21:51:04.446590: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcuda.so.1
# 2020-07-14 21:51:04.458419: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-07-14 21:51:04.458698: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1555] Found device 0 with properties:
# pciBusID: 0000:01:00.0 name: GeForce GTX 1060 computeCapability: 6.1
# ...

# %%
# %matplotlib inline

# %reload_ext autoreload
# %autoreload 2

import keras

from keras_retinanet.models import retinanet
from keras_retinanet import models
from keras_retinanet.utils.image import read_image_bgr, preprocess_image, resize_image
from keras_retinanet.utils.visualization import draw_box, draw_caption
from keras_retinanet.utils.colors import label_color

import matplotlib.pyplot as plt
import cv2
import os
import numpy as np
import time
import json
from random import shuffle

import tensorflow as tf

def get_session():
    config = tf.compat.v1.ConfigProto()
    config.gpu_options.allow_growth = True
    return tf.compat.v1.Session(config=config)

tf.compat.v1.keras.backend.set_session(get_session())
# Out:
# Using TensorFlow backend.

# %%
model_path = 'data/snapshots_penguin/final_model_penguin.h5'

print(model_path)

model = models.load_model(model_path, backbone_name='resnet50')

print(model.summary())

labels_to_names = {0: 'penguin'}
# Out:
# data/snapshots_penguin/final/final_model_penguin.h5
# tracking <tf.Variable 'Variable:0' shape=(9, 4) dtype=float32, numpy=
# array([[ -7.601329 ,  -5.4425516,   7.601329 ,   5.4425516],
#        [-12.007074 ,  -8.597065 ,  12.007074 ,   8.597065 ],
#        [-19.362589 , -13.863615 ,  19.362589 ,  13.863615 ],
#        [ -6.432    ,  -6.432    ,   6.432    ,   6.432    ],
#        [-10.16     , -10.16     ,  10.16     ,  10.16     ],
#        [-16.384    , -16.384    ,  16.384    ,  16.384    ],
#        [ -5.4438148,  -7.5995655,   5.4438148,   7.5995655],
#        [ -8.59906  , -12.004289 ,   8.59906  ,  12.004289 ],
#        [-13.866832 , -19.358097 ,  13.866832 ,  19.358097 ]],
#       dtype=float32)> anchors
# tracking <tf.Variable 'Variable:0' shape=(9, 4) dtype=float32, numpy=
# array([[-15.202658 , -10.885103 ,  15.202658 ,  10.885103 ],
#        [-24.014149 , -17.19413  ,  24.014149 ,  17.19413  ],
#        [-38.725178 , -27.72723  ,  38.725178 ,  27.72723  ],
# ...

# %%
image_dir = "data/mosaics/penguin/SteepleJason_Blob_Nov2019_Reprocess_transparent_mosaic_group1_500x500_overlap40/"

image_list = []
for root, dirs, files in os.walk(image_dir):
    for filename in files:
        if filename.lower().endswith(('.png')):
            image_list.append(image_dir + filename)
print(len(image_list))
# Out:
# 832

# %%
visualize = True
min_score = 0.5

detections = {}

total_time = 0

count = 0
detection_iterations = 10
shuffle(image_list)

for image_path in image_list: 
    if count > detection_iterations:
        break
    else: 
        count +=1
    
    image = read_image_bgr(image_path)
    
    if visualize:
        draw = image.copy()
        draw = cv2.cvtColor(draw, cv2.COLOR_BGR2RGB)
        
    image = preprocess_image(image)
    image, scale = resize_image(image)
    
    start = time.time()
    boxes, scores, labels = model.predict_on_batch(np.expand_dims(image, axis=0))
    total_time += time.time() - start 
    
    boxes /= scale
    if any(score >= min_score for score in scores [0]):
        detections[image_path] = []
        
    for box, score, label in zip(boxes[0], scores[0], labels[0]):
        if score < min_score:
            break
            
        b = box.astype(int)
        detections[image_path].append({"box" : b, "label" : label, "score" : score})
        
        if visualize: 
            color = label_color(label)
            
            draw_box(draw, b, color=color)
            
            caption = "{} {:.3f}".format(labels_to_names[label], score)
            draw_caption(draw, b, caption)
            
    if any(score >= min_score for score in scores[0]):
        if visualize:
            plt.figure(figsize=(12, 12))
            plt.axis('off')
            plt.imshow(draw)
            plt.show()
            
print("Finished, time per image:", total_time/len(image_list))
# Out:
# Finished, time per image: 0.0016296024505908673

# %%
min_score = 0.5

detections = {}

total_time = 0

for image_path in image_list:
    
    image = read_image_bgr(image_path)
          
    image = preprocess_image(image)
    image, scale = resize_image(image)
    
    start = time.time()
    boxes, scores, labels = model.predict_on_batch(np.expand_dims(image, axis=0))
    total_time += time.time() - start
    
    boxes /= scale 
        
    if any(score >= min_score for score in scores[0]):
        detections[image_path] = []
    
    for box, score, label in zip(boxes[0], scores[0], labels[0]):
        if score < min_score:
            break
        
        b = box.astype(int)    
        detections[image_path].append({"box" : b, "label" : label, "score" : score})
        
            
print("Finished, time per image:", total_time/len(image_list))
# Out:
# Finished, time per image: 0.12047423279056182

# %%
class MyEncoder(json.JSONEncoder):
    def default(self, obj):
        if isinstance(obj, np.integer):
            return int(obj)
        elif isinstance(obj, np.floating):
            return float(obj)
        elif isinstance(obj, np.ndarray):
            return obj.tolist()
        else:
            return super(MyEncoder, self).default(obj)

# %%
with open('data/detections_penguin/detections_steeplejason_blob_500x500_overlap40.json', 'w') as fp:
    json.dump(detections, fp, cls=MyEncoder)
