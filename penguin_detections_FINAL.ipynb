# %%
! ../keras-retinanet/keras_retinanet/bin/train.py --weights data/resnet50_coco_best_v2.1.0.h5 \
--steps 500 --epochs 50 \
--snapshot-path data/snapshots_penguin/final \
--random-transform \
--config config_penguin/config.ini \
csv data/mosaics/labeled_tiles_penguin/train_annotations_final.csv data/mosaics/labeled_tiles_penguin/classes.csv \
--val-annotations data/mosaics/labeled_tiles_penguin/val_annotations_final.csv
# Out:
# Using TensorFlow backend.
# 2020-05-06 17:52:10.232620: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libnvinfer.so.6
# 2020-05-06 17:52:10.233745: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libnvinfer_plugin.so.6
# COMET INFO: old comet version (3.1.4) detected. current: 3.1.6 please update your comet lib with command: `pip install --no-cache-dir --upgrade comet_ml`
# COMET WARNING: Failing to collect the installed os packages
# COMET INFO: Experiment is live on comet.ml https://www.comet.ml/madelinehayes/steeple-jason/44b0e0b7e3a140588603872eeef70c4c
#
# Creating model, this may take a second...
# 2020-05-06 17:52:12.736643: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcuda.so.1
# ...

# %%
! ../keras-retinanet/keras_retinanet/bin/convert_model.py --config config_penguin/config.ini data/snapshots_penguin/final/resnet50_csv_19.h5 data/snapshots_penguin/final/final_model_penguin.h5
# Out:
# Using TensorFlow backend.
# 2020-05-06 19:13:53.886659: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libnvinfer.so.6
# 2020-05-06 19:13:53.894375: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libnvinfer_plugin.so.6
# 2020-05-06 19:13:54.766908: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcuda.so.1
# 2020-05-06 19:13:54.794466: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-05-06 19:13:54.794780: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1555] Found device 0 with properties:
# pciBusID: 0000:01:00.0 name: GeForce GTX 1060 computeCapability: 6.1
# coreClock: 1.6705GHz coreCount: 10 deviceMemorySize: 5.94GiB deviceMemoryBandwidth: 178.99GiB/s
# ...

# %%
! ../keras-retinanet/keras_retinanet/bin/evaluate.py --config config_penguin/config.ini csv data/mosaics/labeled_tiles_penguin/test_annotations_final.csv data/mosaics/labeled_tiles_penguin/classes.csv data/snapshots_penguin/final/final_model_penguin.h5
# Out:
# Using TensorFlow backend.
# 2020-05-06 19:14:54.273831: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libnvinfer.so.6
# 2020-05-06 19:14:54.275079: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libnvinfer_plugin.so.6
# Loading model, this may take a second...
# 2020-05-06 19:14:55.188246: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcuda.so.1
# 2020-05-06 19:14:55.205723: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-05-06 19:14:55.206159: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1555] Found device 0 with properties:
# pciBusID: 0000:01:00.0 name: GeForce GTX 1060 computeCapability: 6.1
# ...

# %%
! ../keras-retinanet/keras_retinanet/bin/evaluate.py --config config_penguin/config.ini csv data/mosaics/labeled_tiles_penguin/val_annotations_final.csv data/mosaics/labeled_tiles_penguin/classes.csv data/snapshots_penguin/final/final_model_penguin.h5
# Out:
# Using TensorFlow backend.
# 2020-05-06 19:15:13.697988: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libnvinfer.so.6
# 2020-05-06 19:15:13.699354: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libnvinfer_plugin.so.6
# Loading model, this may take a second...
# 2020-05-06 19:15:14.571638: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcuda.so.1
# 2020-05-06 19:15:14.592689: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-05-06 19:15:14.592993: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1555] Found device 0 with properties:
# pciBusID: 0000:01:00.0 name: GeForce GTX 1060 computeCapability: 6.1
# ...

# %%
# %matplotlib inline

# %reload_ext autoreload
# %autoreload 2

import keras

from keras_retinanet.models import retinanet
from keras_retinanet import models
from keras_retinanet.utils.image import read_image_bgr, preprocess_image, resize_image
from keras_retinanet.utils.visualization import draw_box, draw_caption
from keras_retinanet.utils.colors import label_color

import matplotlib.pyplot as plt
import cv2
import os
import numpy as np
import time
import json
from random import shuffle

import tensorflow as tf

def get_session():
    config = tf.compat.v1.ConfigProto()
    config.gpu_options.allow_growth = True
    return tf.compat.v1.Session(config=config)

tf.compat.v1.keras.backend.set_session(get_session())
# Out:
# Using TensorFlow backend.

# %%
model_path = 'data/snapshots_penguin/final/final_model_penguin.h5'

print(model_path)

model = models.load_model(model_path, backbone_name='resnet50')

print(model.summary())

labels_to_names = {0: 'penguin'}
# Out:
# data/snapshots_penguin/final/final_model_penguin.h5
# tracking <tf.Variable 'Variable:0' shape=(9, 4) dtype=float32, numpy=
# array([[ -7.600757 ,  -5.388937 ,   7.600757 ,   5.388937 ],
#        [-12.14221  ,  -8.608827 ,  12.14221  ,   8.608827 ],
#        [-19.0779   , -13.526231 ,  19.0779   ,  13.526231 ],
#        [ -6.4      ,  -6.4      ,   6.4      ,   6.4      ],
#        [-10.224    , -10.224    ,  10.224    ,  10.224    ],
#        [-16.064    , -16.064    ,  16.064    ,  16.064    ],
#        [ -5.3897724,  -7.599579 ,   5.3897724,   7.599579 ],
#        [ -8.610162 , -12.140327 ,   8.610162 ,  12.140327 ],
#        [-13.528328 , -19.074942 ,  13.528328 ,  19.074942 ]],
#       dtype=float32)> anchors
# tracking <tf.Variable 'Variable:0' shape=(9, 4) dtype=float32, numpy=
# array([[-15.201514, -10.777874,  15.201514,  10.777874],
#        [-24.28442 , -17.217653,  24.28442 ,  17.217653],
#        [-38.1558  , -27.052462,  38.1558  ,  27.052462],
# ...

# %%
image_dir = "data/mosaics/GrandJason_SWRightThird_Nov2019_transparent_mosaic_group1_250x250/"

image_list = []
for root, dirs, files in os.walk(image_dir):
    for filename in files:
        if filename.lower().endswith(('.png')):
            image_list.append(image_dir + filename)
print(len(image_list))
# Out:
# 20383

# %%
visualize = True
min_score = 0.5

detections = {}

total_time = 0

count = 0
detection_iterations = 10
shuffle(image_list)

for image_path in image_list: 
    if count > detection_iterations:
        break
    else: 
        count +=1
    
    image = read_image_bgr(image_path)
    
    if visualize:
        draw = image.copy()
        draw = cv2.cvtColor(draw, cv2.COLOR_BGR2RGB)
        
    image = preprocess_image(image)
    image, scale = resize_image(image)
    
    start = time.time()
    boxes, scores, labels = model.predict_on_batch(np.expand_dims(image, axis=0))
    total_time += time.time() - start 
    
    boxes /= scale
    if any(score >= min_score for score in scores [0]):
        detections[image_path] = []
        
    for box, score, label in zip(boxes[0], scores[0], labels[0]):
        if score < min_score:
            break
            
        b = box.astype(int)
        detections[image_path].append({"box" : b, "label" : label, "score" : score})
        
        if visualize: 
            color = label_color(label)
            
            draw_box(draw, b, color=color)
            
            caption = "{} {:.3f}".format(labels_to_names[label], score)
            draw_caption(draw, b, caption)
            
    if any(score >= min_score for score in scores[0]):
        if visualize:
            plt.figure(figsize=(10, 10))
            plt.axis('off')
            plt.imshow(draw)
            plt.show()
            
print("Finished, time per image:", total_time/len(image_list))
# Out:
# Finished, time per image: 0.0002197116512502017

# %%
min_score = 0.5

detections = {}

total_time = 0

for image_path in image_list:
    
    image = read_image_bgr(image_path)
          
    image = preprocess_image(image)
    image, scale = resize_image(image)
    
    start = time.time()
    boxes, scores, labels = model.predict_on_batch(np.expand_dims(image, axis=0))
    total_time += time.time() - start
    
    boxes /= scale 
        
    if any(score >= min_score for score in scores[0]):
        detections[image_path] = []
    
    #boxes = non_max_suppression_fast(boxes[0], 0.1)
    
    for box, score, label in zip(boxes[0], scores[0], labels[0]):
        if score < min_score:
            break
        
        b = box.astype(int)    
        #pick = non_max_suppression_fast(boxes, 0.3)
        detections[image_path].append({"box" : b, "label" : label, "score" : score})
        
            
print("Finished, time per image:", total_time/len(image_list))
# Out:
# Finished, time per image: 0.12310222431344633

# %%
class MyEncoder(json.JSONEncoder):
    def default(self, obj):
        if isinstance(obj, np.integer):
            return int(obj)
        elif isinstance(obj, np.floating):
            return float(obj)
        elif isinstance(obj, np.ndarray):
            return obj.tolist()
        else:
            return super(MyEncoder, self).default(obj)

# %%
with open('data/detections_penguin/final/detections_grandjason_seblob_500x500.json', 'w') as fp:
    json.dump(detections, fp, cls=MyEncoder)
